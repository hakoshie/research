# %%
import pandas as pd

# %%
f_columns=["year","id","efficacy","rx_agg","rx_pro_agg","rx_pro_dom","otc_agg","otc_pro_agg","otc_pro_dom","self_agg","self_pro_agg","self_pro_dom"]
final_df=pd.DataFrame(columns=f_columns)
final_df
# Out:
# Empty DataFrame
# Columns: [year, id, efficacy, rx_agg, rx_pro_agg, rx_pro_dom, otc_agg, otc_pro_agg, otc_pro_dom, self_agg, self_pro_agg, self_pro_dom]
# Index: []

# %% [markdown]
# 国内向け出荷額だけ見よう

# %%
def data_extract(final_df,names,header,index,year,drop=0):
    for it,name in enumerate(names):
        if drop==0:
            data=pd.read_excel(name,header=None,names=header)
        else: 
            data=pd.read_excel(name,header=None)
            data.dropna(how="all",inplace=True)
            data.dropna(how="all",inplace=True,axis=1)
            data.columns=header
            data.reset_index(inplace=True)
        column_names=f_columns[1:]
        row_list=[data.loc[index,cname] if cname in header else 0 for cname in column_names]
        row_list.insert(0,year+it)
        final_df=pd.concat([final_df,pd.DataFrame(row_list,index=f_columns).T],ignore_index=False)
    return final_df

# %%
# type 1
# header =[]
names=[
"2015-4.xls",
# "2015-5.xls",
"2016-4.xls",
# "2016-5.xls",
"2017-4.xls",
# "2017-5.xls",
"2018-4.xls",
# "2018-5.xls"
]
year=2015
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","etc_pro_dom","etc_pro_im","etc_im","id2","efficacy2","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
index=190
final_df=data_extract(final_df,names,header,index,year)

# %%
final_df
# Out:
#    year   id     efficacy     rx_agg rx_pro_agg rx_pro_dom  otc_agg  \
# 0  2015  449  その他のアレルギー用薬  306606080  223760998  101932009  3264482
# 0  2016  449  その他のアレルギー用薬  272096958  199155750  105345546  7110132
# 0  2017  449  その他のアレルギー用薬  242778979  171141618  109661900  5019869
# 0  2018  449  その他のアレルギー用薬  198205309  135539542   88655487  7837161
#
#   otc_pro_agg otc_pro_dom self_agg self_pro_agg self_pro_dom
# 0     2378629     2358602  3220969      2335116      2315089
# 0     5789982     5753243  7072689      5752539      5715800
# 0     3789685     3391034  4945376      3715192      3316541
# 0     6639693     5955210  7724839      6527371      5842888

# %%
len(header)
# Out:
# 35

# %%
# 何もない列があるP
names=[
"yakuji-h25tou-04.xls",
# "yakuji-h25tou-05.xls",
"yakuji-h26tou-04.xls",
# "yakuji-h26tou-05.xls"
]
year=2013
index=189
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","null","id2","efficacy2","etc_pro_dom","etc_pro_im","etc_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
final_df=data_extract(final_df,names,header,index,year)
# Out:
# 31

# %%
final_df
# Out:
#    year   id     efficacy     rx_agg rx_pro_agg rx_pro_dom  otc_agg  \
# 0  2015  449  その他のアレルギー用薬  306606080  223760998  101932009  3264482
# 0  2016  449  その他のアレルギー用薬  272096958  199155750  105345546  7110132
# 0  2017  449  その他のアレルギー用薬  242778979  171141618  109661900  5019869
# 0  2018  449  その他のアレルギー用薬  198205309  135539542   88655487  7837161
# 0  2013  449  その他のアレルギー用薬  341944849  244981041  125347150  2347619
# 0  2014  449  その他のアレルギー用薬  276190906  209248113  100659723  1819936
#
#   otc_pro_agg otc_pro_dom self_agg self_pro_agg self_pro_dom
# 0     2378629     2358602  3220969      2335116      2315089
# 0     5789982     5753243  7072689      5752539      5715800
# 0     3789685     3391034  4945376      3715192      3316541
# 0     6639693     5955210  7724839      6527371      5842888
# 0     2347619     1560896        0            0            0
# 0     1638116     1109093        0            0            0

# %%
names=[
"yakuji-2020-03.xlsx",
# "yakuji-2020-04.xlsx",
]
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
index=139
year=2019
final_df=data_extract(final_df,names,header,index,year,drop=1)
# Out:
# 28

# %%
final_df
# Out:
#    year   id     efficacy       rx_agg   rx_pro_agg  rx_pro_dom     otc_agg  \
# 0  2015  449  その他のアレルギー用薬    306606080    223760998   101932009     3264482
# 0  2016  449  その他のアレルギー用薬    272096958    199155750   105345546     7110132
# 0  2017  449  その他のアレルギー用薬    242778979    171141618   109661900     5019869
# 0  2018  449  その他のアレルギー用薬    198205309    135539542    88655487     7837161
# 0  2013  449  その他のアレルギー用薬    341944849    244981041   125347150     2347619
# 0  2014  449  その他のアレルギー用薬    276190906    209248113   100659723     1819936
# 0  2019  449  その他のアレルギー用薬  246,609,799  215,258,887  34,526,556  13,050,962
#
#   otc_pro_agg otc_pro_dom    self_agg self_pro_agg self_pro_dom
# 0     2378629     2358602     3220969      2335116      2315089
# 0     5789982     5753243     7072689      5752539      5715800
# 0     3789685     3391034     4945376      3715192      3316541
# 0     6639693     5955210     7724839      6527371      5842888
# 0     2347619     1560896           0            0            0
# 0     1638116     1109093           0            0            0
# 0   9,493,036   6,063,340  13,039,331    9,481,405    6,063,340

# %%
names=[
"yakuji-2021-03.xlsx",
# "yakuji-2021-04.xlsx",
"yakuji-2022-03.xlsx",
# "yakuji-2022-04.xlsx",
]
index=140
year=2020
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
final_df=data_extract(final_df,names,header,index,year,drop=1)
# Out:
# 28

# %%
# for column in final_df.columns:
final_df=final_df.replace(',','',regex=True)
final_df=final_df.sort_values("year")
# final_df=final_df.set_index("year")
for col in final_df.columns:
    if col!="efficacy":
        final_df[col]=final_df[col].astype(int)
final_df=final_df.set_index("year")
final_df
# Out:
#        id     efficacy     rx_agg  rx_pro_agg  rx_pro_dom   otc_agg  \
# year
# 2013  449  その他のアレルギー用薬  341944849   244981041   125347150   2347619
# 2014  449  その他のアレルギー用薬  276190906   209248113   100659723   1819936
# 2015  449  その他のアレルギー用薬  306606080   223760998   101932009   3264482
# 2016  449  その他のアレルギー用薬  272096958   199155750   105345546   7110132
# 2017  449  その他のアレルギー用薬  242778979   171141618   109661900   5019869
# 2018  449  その他のアレルギー用薬  198205309   135539542    88655487   7837161
# 2019  449  その他のアレルギー用薬  246609799   215258887    34526556  13050962
# 2020  449  その他のアレルギー用薬  243360043   179898389    37051529   7843813
# 2021  449  その他のアレルギー用薬  222931862   151727406    37317805   6767409
#
#       otc_pro_agg  otc_pro_dom  self_agg  self_pro_agg  self_pro_dom
# year
# 2013      2347619      1560896         0             0             0
# 2014      1638116      1109093         0             0             0
# 2015      2378629      2358602   3220969       2335116       2315089
# 2016      5789982      5753243   7072689       5752539       5715800
# 2017      3789685      3391034   4945376       3715192       3316541
# 2018      6639693      5955210   7724839       6527371       5842888
# 2019      9493036      6063340  13039331       9481405       6063340
# 2020      7142773      3330218   7797490       7096450       3330218
# 2021      6626987      4370093   6661224       6520802       4361393

# %%
final_df.to_csv("data_prod_processed.csv")

# %%
final_df.plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
final_df.plot(y=["otc_agg","otc_pro_agg"])
final_df.plot(y=["self_agg","self_pro_agg"])
# Out:
# <AxesSubplot: xlabel='year'>
