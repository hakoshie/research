# %%
import pandas as pd

# %%
f_columns=["year","rx_agg","rx_pro_agg","rx_pro_dom","otc_agg","otc_pro_agg","otc_pro_dom","self_agg","self_pro_agg","self_pro_dom"]
final_df=pd.DataFrame(columns=f_columns)
final_df
# Out:
# Empty DataFrame
# Columns: [year, rx_agg, rx_pro_agg, rx_pro_dom, otc_agg, otc_pro_agg, otc_pro_dom, self_agg, self_pro_agg, self_pro_dom]
# Index: []

# %% [markdown]
# 国内向け出荷額だけ見よう

# %%
# type 1
# header =[]
names=[
"2015-4.xls",
# "2015-5.xls",
"2016-4.xls",
# "2016-5.xls",
"2017-4.xls",
# "2017-5.xls",
"2018-4.xls",
# "2018-5.xls"
]
year=2015
header=["id","class","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","etc_pro_dom","etc_pro_im","etc_im","id2","class2","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
index=190
for it,name in enumerate(names):
    data=pd.read_excel(name,header=None,names=header)
    print(data.loc[190,"id"],data.loc[190,"rx_pro_dom"],data.loc[190,"otc_pro_dom"],data.loc[190,"self_pro_dom"])
    final_df=pd.concat([final_df,pd.DataFrame([year+it,data.loc[index,"rx_agg"],data.loc[index,"rx_pro_agg"],data.loc[index,"rx_pro_dom"],
    data.loc[index,"otc_agg"],data.loc[index,"otc_pro_agg"],data.loc[index,"otc_pro_dom"],
    data.loc[index,"self_agg"],data.loc[index,"self_pro_agg"],data.loc[index,"self_pro_dom"]],index=f_columns).T],ignore_index=False)
# Out:
# 449 101932009 2358602 2315089
# 449 105345546 5753243 5715800
# 449 109661900 3391034 3316541
# 449 88655487 5955210 5842888

# %%
final_df
# Out:
#    year     rx_agg rx_pro_agg rx_pro_dom  otc_agg otc_pro_agg otc_pro_dom  \
# 0  2015  306606080  223760998  101932009  3264482     2378629     2358602
# 0  2016  272096958  199155750  105345546  7110132     5789982     5753243
# 0  2017  242778979  171141618  109661900  5019869     3789685     3391034
# 0  2018  198205309  135539542   88655487  7837161     6639693     5955210
#
#   self_agg self_pro_agg self_pro_dom
# 0  3220969      2335116      2315089
# 0  7072689      5752539      5715800
# 0  4945376      3715192      3316541
# 0  7724839      6527371      5842888

# %%
len(header)
# Out:
# 35

# %%
final_df
# Out:
#    year     rx_agg rx_pro_agg rx_pro_dom  otc_agg otc_pro_agg otc_pro_dom  \
# 0  2015  306606080  223760998  101932009  3264482     2378629     2358602
# 0  2016  272096958  199155750  105345546  7110132     5789982     5753243
# 0  2017  242778979  171141618  109661900  5019869     3789685     3391034
# 0  2018  198205309  135539542   88655487  7837161     6639693     5955210
#
#   self_agg self_pro_agg self_pro_dom
# 0  3220969      2335116      2315089
# 0  7072689      5752539      5715800
# 0  4945376      3715192      3316541
# 0  7724839      6527371      5842888

# %%
# 何もない列があるP
names2=[
"yakuji-h25tou-04.xls",
# "yakuji-h25tou-05.xls",
"yakuji-h26tou-04.xls",
# "yakuji-h26tou-05.xls"
]
year=2013
index=189
header=["id","class","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","null","id2","class2","etc_pro_dom","etc_pro_im","etc_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
for it,name in enumerate(names2):
    data=pd.read_excel(name,header=None,names=header)
    # print(data.iloc[16])
    print(data.loc[index,"id"]==449)
    print(data.loc[index,"id"],data.loc[index,"rx_pro_dom"],data.loc[index,"otc_pro_dom"])
    final_df=pd.concat([final_df,pd.DataFrame([year+it,data.loc[index,"rx_agg"],data.loc[index,"rx_pro_agg"],data.loc[index,"rx_pro_dom"],
    data.loc[index,"otc_agg"],data.loc[index,"otc_pro_agg"],data.loc[index,"otc_pro_dom"],
   0,0,0],index=f_columns).T],ignore_index=False)
# Out:
# 31
# True
# 449 125347150 1560896
# True
# 449 100659723 1109093

# %%
final_df
# Out:
#    year     rx_agg rx_pro_agg rx_pro_dom  otc_agg otc_pro_agg otc_pro_dom  \
# 0  2015  306606080  223760998  101932009  3264482     2378629     2358602
# 0  2016  272096958  199155750  105345546  7110132     5789982     5753243
# 0  2017  242778979  171141618  109661900  5019869     3789685     3391034
# 0  2018  198205309  135539542   88655487  7837161     6639693     5955210
# 0  2013  341944849  244981041  125347150  2347619     2347619     1560896
# 0  2014  276190906  209248113  100659723  1819936     1638116     1109093
#
#   self_agg self_pro_agg self_pro_dom
# 0  3220969      2335116      2315089
# 0  7072689      5752539      5715800
# 0  4945376      3715192      3316541
# 0  7724839      6527371      5842888
# 0        0            0            0
# 0        0            0            0

# %%
names=[
"yakuji-2020-03.xlsx",
# "yakuji-2020-04.xlsx",
]
header=["id","class","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
index=139
year=2019
for it,name in enumerate(names):
    data=pd.read_excel(name,header=None)
    data.dropna(how="all",inplace=True)
    data.dropna(how="all",inplace=True,axis=1)
    data.columns=header
    data.reset_index(inplace=True)
    # print(data.iloc[index])
    print(data.loc[index,"id"],data.loc[index,"class"])
    print(data.loc[index,"id"],data.loc[index,"rx_pro_dom"],data.loc[index,"otc_pro_dom"])
    final_df=pd.concat([final_df,pd.DataFrame([year+it,data.loc[index,"rx_agg"],data.loc[index,"rx_pro_agg"],data.loc[index,"rx_pro_dom"],
    data.loc[index,"otc_agg"],data.loc[index,"otc_pro_agg"],data.loc[index,"otc_pro_dom"],
    data.loc[index,"self_agg"],data.loc[index,"self_pro_agg"],data.loc[index,"self_pro_dom"]],index=f_columns).T],ignore_index=False)
# Out:
# 28
# 449 その他のアレルギー用薬
# 449 34,526,556 6,063,340

# %%
final_df
# Out:
#    year       rx_agg   rx_pro_agg  rx_pro_dom     otc_agg otc_pro_agg  \
# 0  2015    306606080    223760998   101932009     3264482     2378629
# 0  2016    272096958    199155750   105345546     7110132     5789982
# 0  2017    242778979    171141618   109661900     5019869     3789685
# 0  2018    198205309    135539542    88655487     7837161     6639693
# 0  2013    341944849    244981041   125347150     2347619     2347619
# 0  2014    276190906    209248113   100659723     1819936     1638116
# 0  2019  246,609,799  215,258,887  34,526,556  13,050,962   9,493,036
#
#   otc_pro_dom    self_agg self_pro_agg self_pro_dom
# 0     2358602     3220969      2335116      2315089
# 0     5753243     7072689      5752539      5715800
# 0     3391034     4945376      3715192      3316541
# 0     5955210     7724839      6527371      5842888
# 0     1560896           0            0            0
# 0     1109093           0            0            0
# ...

# %%
names=[
"yakuji-2021-03.xlsx",
# "yakuji-2021-04.xlsx",
"yakuji-2022-03.xlsx",
# "yakuji-2022-04.xlsx",
]
index=140
year=2020
header=["id","class","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
for it,name in enumerate(names):
    data=pd.read_excel(name,header=None)
    data.dropna(how="all",inplace=True)
    data.dropna(how="all",inplace=True,axis=1)
    data.columns=header
    data.reset_index(inplace=True)
    print(data.loc[index,"id"],data.loc[index,"class"])
    print(data.loc[index,"id"],data.loc[index,"rx_pro_dom"],data.loc[index,"otc_pro_dom"])
    final_df=pd.concat([final_df,pd.DataFrame([year+it,data.loc[index,"rx_agg"],data.loc[index,"rx_pro_agg"],data.loc[index,"rx_pro_dom"],
    data.loc[index,"otc_agg"],data.loc[index,"otc_pro_agg"],data.loc[index,"otc_pro_dom"],
    data.loc[index,"self_agg"],data.loc[index,"self_pro_agg"],data.loc[index,"self_pro_dom"]],index=f_columns).T],ignore_index=False)
# Out:
# 28
# 449 その他のアレルギー用薬
# 449 37,051,529 3,330,218
# 449 その他のアレルギー用薬
# 449 37,317,805 4,370,093

# %%
# for column in final_df.columns:
final_df=final_df.replace(',','',regex=True)
final_df=final_df.sort_values("year")
# final_df=final_df.set_index("year")
for col in final_df.columns:
    final_df[col]=final_df[col].astype(int)
final_df=final_df.set_index("year")
final_df
# Out:
#          rx_agg  rx_pro_agg  rx_pro_dom   otc_agg  otc_pro_agg  otc_pro_dom  \
# year
# 2013  341944849   244981041   125347150   2347619      2347619      1560896
# 2014  276190906   209248113   100659723   1819936      1638116      1109093
# 2015  306606080   223760998   101932009   3264482      2378629      2358602
# 2016  272096958   199155750   105345546   7110132      5789982      5753243
# 2017  242778979   171141618   109661900   5019869      3789685      3391034
# 2018  198205309   135539542    88655487   7837161      6639693      5955210
# 2019  246609799   215258887    34526556  13050962      9493036      6063340
# 2020  243360043   179898389    37051529   7843813      7142773      3330218
# 2021  222931862   151727406    37317805   6767409      6626987      4370093
#
#       self_agg  self_pro_agg  self_pro_dom
# year
# 2013         0             0             0
# 2014         0             0             0
# 2015   3220969       2335116       2315089
# ...

# %%
final_df.to_csv("data_prod_processed.csv")

# %%
final_df.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
final_df.plot(y=["otc_agg","otc_pro_agg"])
final_df.plot(y=["self_agg","self_pro_agg"])
# Out:
# <AxesSubplot:xlabel='year'>
