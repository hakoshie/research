# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from linearmodels.panel.data import PanelData
from linearmodels.panel import PanelOLS, PooledOLS, RandomEffects, compare
import matplotlib.pyplot as plt
from plot_result import plot_result

# %%
df=pd.read_csv("../../data/merged/len3_ship_DN.csv",encoding="shift-jis",index_col=0)
# sum ver.
# df=pd.read_csv("../data/merged/len3_ship_sum_DN.csv",encoding="shift-jis",index_col=0)

# %% [markdown]
# Estimation

# %%
# normalization of year
# 2008で正規化するかで結構estimateが変わります、1ぐらい
# df["year"]=df["year"]-2008

#ここはかなり重要でセレクションバイアスみたいなので有意性が変わるらしい
df=df.loc[df["otc_dom"]>0]
df=df.loc[df["rx_dom"]>0]
df=df.loc[df["generic_share_q"]>0]
# make log columns
df["log_rx_dom"]=np.log(df["rx_dom"])
df["log_otc_dom"]=np.log(df["otc_dom"])
df["log_stock_rx_lag"]=np.log(df["stock_rx_lag"]+0.001)
df["log_stock_otc_lag"]=np.log(df["stock_otc_lag"]+0.001)
df["year_trend"]=df["year"]-2008

# %%
df=df.set_index(["id","year"])
df.info()
# make this to paneldata
df=PanelData(df)
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 249 entries, (114, 2008) to (799, 2021)
# Data columns (total 99 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   efficacy           249 non-null    object
#  1   rx_dom             249 non-null    int64
#  2   otc_dom            249 non-null    float64
#  3   self_dom           249 non-null    int64
#  4   stock_rx           249 non-null    float64
#  5   stock_otc          249 non-null    float64
#  6   stock_self         249 non-null    float64
#  7   stock_rx_lag       232 non-null    float64
#  8   stock_otc_lag      232 non-null    float64
#  9   stock_self_lag     232 non-null    float64
#  10  Approved           249 non-null    float64
#  11  KEGG               249 non-null    object
#  12  Ingredient         249 non-null    object
#  13  date               249 non-null    object
#  14  release_year       249 non-null    float64
#  15  成分                 249 non-null    object
#  16  variable           249 non-null    object
#  17  elapsed            249 non-null    float64
#  18  elapsed_m14        249 non-null    int64
#  19  elapsed_m13        249 non-null    int64
#  20  elapsed_m12        249 non-null    int64
#  21  elapsed_m11        249 non-null    int64
#  22  elapsed_m10        249 non-null    int64
#  23  elapsed_m9         249 non-null    int64
#  24  elapsed_m8         249 non-null    int64
#  25  elapsed_m7         249 non-null    int64
#  26  elapsed_m6         249 non-null    int64
#  27  elapsed_m5         249 non-null    int64
#  28  elapsed_m4         249 non-null    int64
#  29  elapsed_m3         249 non-null    int64
#  30  elapsed_m2         249 non-null    int64
#  31  elapsed_m1         249 non-null    int64
#  32  elapsed_0          249 non-null    int64
#  33  elapsed_1          249 non-null    int64
#  34  elapsed_2          249 non-null    int64
#  35  elapsed_3          249 non-null    int64
#  36  elapsed_4          249 non-null    int64
#  37  elapsed_5          249 non-null    int64
#  38  elapsed_6          249 non-null    int64
#  39  elapsed_7          249 non-null    int64
#  40  elapsed_8          249 non-null    int64
#  41  elapsed_9          249 non-null    int64
#  42  elapsed_10         249 non-null    int64
#  43  elapsed_11         249 non-null    int64
#  44  elapsed_12         249 non-null    int64
#  45  elapsed_13         249 non-null    int64
#  46  elapsed_14         249 non-null    int64
#  47  elapsed_15         249 non-null    int64
#  48  elapsed_16         249 non-null    int64
#  49  elapsed_17         249 non-null    int64
#  50  elapsed_18         249 non-null    int64
#  51  elapsed_19         249 non-null    int64
#  52  elapsed_20         249 non-null    int64
#  53  elapsed_21         249 non-null    int64
#  54  elapsed_22         249 non-null    int64
#  55  elapsed_23         249 non-null    int64
#  56  elapsed_24         249 non-null    int64
#  57  elapsed_25         249 non-null    int64
#  58  elapsed_26         249 non-null    int64
#  59  elapsed_27         249 non-null    int64
#  60  elapsed_28         249 non-null    int64
#  61  elapsed_29         249 non-null    int64
#  62  elapsed_30         249 non-null    int64
#  63  elapsed_31         249 non-null    int64
#  64  Year               249 non-null    int64
#  65  generic_per        249 non-null    float64
#  66  薬効分類               249 non-null    float64
#  67  generic_share_q    249 non-null    float64
#  68  generic_share_r    249 non-null    float64
#  69  id_114             249 non-null    int64
#  70  id_121             249 non-null    int64
#  71  id_123             249 non-null    int64
#  72  id_131             249 non-null    int64
#  73  id_132             249 non-null    int64
#  74  id_218             249 non-null    int64
#  75  id_223             249 non-null    int64
#  76  id_225             249 non-null    int64
#  77  id_229             249 non-null    int64
#  78  id_231             249 non-null    int64
#  79  id_232             249 non-null    int64
#  80  id_239             249 non-null    int64
#  81  id_245             249 non-null    int64
#  82  id_252             249 non-null    int64
#  83  id_259             249 non-null    int64
#  84  id_264             249 non-null    int64
#  85  id_265             249 non-null    int64
#  86  id_332             249 non-null    int64
#  87  id_339             249 non-null    int64
#  88  id_399             249 non-null    int64
#  89  id_441             249 non-null    int64
#  90  id_449             249 non-null    int64
#  91  id_625             249 non-null    int64
#  92  id_629             249 non-null    int64
#  93  id_799             249 non-null    int64
#  94  log_rx_dom         249 non-null    float64
#  95  log_otc_dom        249 non-null    float64
#  96  log_stock_rx_lag   232 non-null    float64
#  97  log_stock_otc_lag  232 non-null    float64
#  98  year_trend         249 non-null    int64
# dtypes: float64(18), int64(75), object(6)
# memory usage: 194.5+ KB
# (184, 14, 21)

# %% [markdown]
# stockのlag(むしろgeneric?)とtime effectは共存できないらしい

# %% [markdown]
# ## RX

# %%
# formula="rx_dom ~ year_trend+elapsed_m10+elapsed_m9+elapsed_m8+elapsed_m7+elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+generic_per+TimeEffects+EntityEffects"
# # stock lag version
# # formula+="+stock_rx_lag"
# # gemeric_per
# formula+=" + generic_per"
# mod_fe=PanelOLS.from_formula(formula, data=df,drop_absorbed=True)
# res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
# # print(res_fe.summary.tables[1])
# # print(res_fe.summary.tables[0])
# print(res_fe)
# plot_result(res_fe,file_name="rx",title="rx",period=25,insert_index=9,time_start=-10)
# # print(x)

# %%
[0]*5
# Out:
# [0, 0, 0, 0, 0]

# %%
# take log
formula="log_rx_dom ~ year_trend+elapsed_m10+elapsed_m9+elapsed_m8+elapsed_m7+elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+TimeEffects+EntityEffects"
# stock lag version
formula+="+log_stock_rx_lag"

# generic_per
# formula+=" + generic_per"

# generic_share_r
# formula+=" + generic_share_r"

# generic_share_q
formula+=" + log(generic_share_q)"

mod_fe=PanelOLS.from_formula(formula, data=df,drop_absorbed=True)
res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
print(res_fe.summary.tables[1])
print(res_fe.summary.tables[0])
plot_result(res_fe,file_name="rx_log",title="log(Rx)",period=25,insert_index=9,time_start=-10)
# Out:
# c:\Users\hakos\AppData\Local\Programs\Python\Python310\lib\site-packages\linearmodels\panel\model.py:1214: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# C:\Users\hakos\AppData\Local\Temp\ipykernel_24668\1077899798.py:16: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# year_trend
#
#   res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# elapsed_m10             -0.0562     0.0873    -0.6434     0.5208     -0.2285      0.1162
# elapsed_m9              -0.0828     0.1558    -0.5316     0.5957     -0.3902      0.2246
# elapsed_m8              -0.0512     0.0970    -0.5283     0.5980     -0.2426      0.1402
# elapsed_m7              -0.0264     0.0774    -0.3416     0.7331     -0.1791      0.1263
# elapsed_m6               0.0386     0.0680     0.5679     0.5708     -0.0956      0.1729
# elapsed_m5               0.0977     0.0884     1.1046     0.2709     -0.0769      0.2722
# elapsed_m4               0.0657     0.0526     1.2487     0.2135     -0.0381      0.1695
# elapsed_m3               0.0268     0.0357     0.7511     0.4536     -0.0437      0.0973
# elapsed_m2               0.0186     0.0518     0.3597     0.7195     -0.0836      0.1209
# elapsed_0                0.0735     0.0514     1.4285     0.1550     -0.0281      0.1750
# elapsed_1                0.0424     0.0569     0.7459     0.4568     -0.0698      0.1547
# elapsed_2                0.0217     0.0652     0.3337     0.7390     -0.1069      0.1504
# elapsed_3               -0.0355     0.0572    -0.6206     0.5357     -0.1485      0.0774
# elapsed_4                0.0034     0.0619     0.0553     0.9559     -0.1188      0.1256
# elapsed_5               -0.0505     0.0516    -0.9796     0.3286     -0.1523      0.0513
# elapsed_6                0.0145     0.0530     0.2731     0.7851     -0.0902      0.1191
# elapsed_7                0.0332     0.0592     0.5610     0.5755     -0.0836      0.1500
# elapsed_8                0.0496     0.0527     0.9409     0.3481     -0.0544      0.1535
# elapsed_9                0.0980     0.0593     1.6530     0.1001     -0.0190      0.2151
# elapsed_10               0.0559     0.0651     0.8573     0.3925     -0.0727      0.1844
# elapsed_11               0.0552     0.0474     1.1659     0.2453     -0.0383      0.1488
# elapsed_12               0.0142     0.0410     0.3472     0.7289     -0.0667      0.0952
# elapsed_13               0.0773     0.0817     0.9461     0.3454     -0.0839      0.2384
# elapsed_14               0.0019     0.0501     0.0383     0.9695     -0.0970      0.1009
# elapsed_15               0.0446     0.0522     0.8537     0.3944     -0.0585      0.1476
# log_stock_rx_lag         0.2455     0.0631     3.8927     0.0001      0.1210      0.3699
# log(generic_share_q)    -0.1160     0.0760    -1.5256     0.1290     -0.2661      0.0341
# ========================================================================================
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             log_rx_dom   R-squared:                        0.2691
# Estimator:                   PanelOLS   R-squared (Between):              0.4113
# No. Observations:                 232   R-squared (Within):               0.1266
# Date:                Tue, Jan 09 2024   R-squared (Overall):              0.4110
# Time:                        00:20:27   Log-likelihood                    70.514
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.3458
# Entities:                          21   P-value                           0.0005
# Avg Obs:                       11.048   Distribution:                  F(27,172)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):          4.349e+13
#                                         P-value                           0.0000
# Time periods:                      13   Distribution:                  F(27,172)
# Avg Obs:                       17.846
# Min Obs:                       17.000
# Max Obs:                       19.000
#
# ================================================================================

# %% [markdown]
# ### OTC

# %%
# formula="otc_dom ~ year_trend+elapsed_m10+elapsed_m9+elapsed_m8+elapsed_m7+elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+generic_per+TimeEffects+EntityEffects"
# # stock lag version
# # formula+="+stock_otc_lag"
# # gemeric_per
# formula+=" + generic_per"
# mod_fe=PanelOLS.from_formula(formula, data=df, drop_absorbed=True)
# # mod_fe=PanelOLS.from_formula(formula, data=df, drop_absorbed=False)
# res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
# print(res_fe.summary.tables[1])
# print(res_fe.summary.tables[0])
# plot_result(res_fe,file_name="otc",title="OTC",period=25,insert_index=9,time_start=-10)

# %%
# take log
formula="log_otc_dom ~elapsed_m10+elapsed_m9+elapsed_m8+elapsed_m7+elapsed_m6+ elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+generic_per+TimeEffects+EntityEffects"

# till 15
formula="log_otc_dom ~elapsed_m10+elapsed_m9+elapsed_m8+elapsed_m7+elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+TimeEffects+EntityEffects"

# stock lag version
formula+="+log_stock_otc_lag"

# year trend
# formula+="+year_trend"

# gemeric_per
# formula+=" + generic_per"

# generic_share_r
# formula+=" + generic_share_r"
# generic_share_q
# formula+=" + generic_share_q"
formula+=" + log(generic_share_q)"


mod_fe=PanelOLS.from_formula(formula, data=df,drop_absorbed=True)
res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
# res_fe=mod_fe.fit()
# print(res_fe.summary.tables[1])
# print(res_fe.summary.tables[0])
print(res_fe)
plot_result(res_fe,file_name="otc_log",title="log(OTC)",period=25,insert_index=9,time_start=-10)
# Out:
# c:\Users\hakos\AppData\Local\Programs\Python\Python310\lib\site-packages\linearmodels\panel\model.py:1214: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            log_otc_dom   R-squared:                        0.3284
# Estimator:                   PanelOLS   R-squared (Between):              0.1741
# No. Observations:                 232   R-squared (Within):               0.3051
# Date:                Tue, Jan 09 2024   R-squared (Overall):              0.1768
# Time:                        00:20:28   Log-likelihood                   -150.44
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.1152
# Entities:                          21   P-value                           0.0000
# Avg Obs:                       11.048   Distribution:                  F(27,172)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):          6.085e+14
#                                         P-value                           0.0000
# Time periods:                      13   Distribution:                  F(27,172)
# Avg Obs:                       17.846
# Min Obs:                       17.000
# Max Obs:                       19.000
#
#                                   Parameter Estimates
# ========================================================================================
#                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------
# elapsed_m10             -0.1567     0.2213    -0.7079     0.4799     -0.5934      0.2801
# elapsed_m9               0.3667     0.2460     1.4906     0.1379     -0.1189      0.8523
# elapsed_m8               0.0469     0.3086     0.1519     0.8794     -0.5622      0.6560
# elapsed_m7               0.1003     0.3209     0.3127     0.7549     -0.5331      0.7338
# elapsed_m6               0.1542     0.2636     0.5851     0.5593     -0.3661      0.6746
# elapsed_m5              -0.1005     0.1501    -0.6692     0.5043     -0.3968      0.1959
# elapsed_m4              -0.0053     0.1797    -0.0296     0.9764     -0.3600      0.3494
# elapsed_m3              -0.0223     0.2322    -0.0961     0.9235     -0.4806      0.4360
# elapsed_m2               0.2417     0.2282     1.0591     0.2910     -0.2088      0.6922
# elapsed_0                0.2251     0.1000     2.2503     0.0257      0.0276      0.4225
# elapsed_1                0.2138     0.1160     1.8440     0.0669     -0.0151      0.4427
# elapsed_2                0.3535     0.1899     1.8617     0.0644     -0.0213      0.7284
# elapsed_3                0.4566     0.1998     2.2851     0.0235      0.0622      0.8510
# elapsed_4                0.5196     0.1809     2.8728     0.0046      0.1626      0.8766
# elapsed_5                0.3782     0.1464     2.5828     0.0106      0.0892      0.6673
# elapsed_6                0.5396     0.1674     3.2231     0.0015      0.2091      0.8700
# elapsed_7                0.5004     0.1241     4.0330     0.0001      0.2555      0.7453
# elapsed_8                0.4549     0.1108     4.1070     0.0001      0.2363      0.6735
# elapsed_9                0.6098     0.1854     3.2893     0.0012      0.2439      0.9758
# elapsed_10               0.6046     0.1949     3.1026     0.0022      0.2200      0.9892
# elapsed_11               0.5073     0.2257     2.2479     0.0259      0.0618      0.9527
# elapsed_12               0.5642     0.1552     3.6365     0.0004      0.2580      0.8705
# elapsed_13               0.4206     0.1584     2.6549     0.0087      0.1079      0.7333
# elapsed_14               0.2875     0.1994     1.4415     0.1513     -0.1062      0.6812
# elapsed_15               0.4069     0.2686     1.5151     0.1316     -0.1232      0.9370
# log_stock_otc_lag        0.0147     0.0152     0.9682     0.3343     -0.0153      0.0447
# log(generic_share_q)    -0.0525     0.2224    -0.2363     0.8135     -0.4915      0.3864
# ========================================================================================
#
# F-test for Poolability: 83.402
# P-value: 0.0000
# Distribution: F(32,172)
#
# Included effects: Entity, Time
