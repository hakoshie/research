# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from linearmodels.panel.data import PanelData
from linearmodels.panel import PanelOLS, PooledOLS, RandomEffects, compare
import matplotlib.pyplot as plt
from plot_result import plot_result

# %%
df=pd.read_csv("../../data/merged/len4_ndb_DN.csv",encoding="shift-jis",index_col=0)

# %%
df=df.loc[df["総計"]>0]
df=df.loc[df["revenue"]>0]
df=df.loc[df["generic_share_q"]>0]
df=df.loc[df["year"]>2014]
df["price"]=df["revenue"]/df["総計"]
df["log_quantity"]=np.log(df["総計"])
df["log_revenue"]=np.log(df["revenue"])
df_generic=df.copy()
df_branded=df.copy()
df_branded=df_branded.loc[df_branded["後発品区分"]==0]
df_generic=df_generic.loc[df_generic["後発品区分"]==1]
df_branded=df_branded.set_index(["id","year"])
df_generic=df_generic.set_index(["id","year"])
df=df.set_index(["id","year"])
df_branded=PanelData(df_branded,convert_dummies=False)
df_generic=PanelData(df_generic,convert_dummies=False)
df=PanelData(df,convert_dummies=False)

# %%
# generic without covariates
formula="log_quantity~elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+TimeEffects+EntityEffects"

# till elapsed_20
# formula="log_quantity~ elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+TimeEffects+EntityEffects"

# add generic_per
# formula+="+log(generic_per)"
# generic_share_r
# formula+=" + generic_share_r"
# generic_share_q
# formula+="+log(薬価)"
# formula+=" + log(generic_share_q)"
# formula+="+log(price)"
mod_fe=PanelOLS.from_formula(formula, data=df_generic,check_rank=False,drop_absorbed=True)
res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
print(res_fe.summary.tables[1])
# print(res_fe.summary.tables[0])
# print(res_fe)
# plot_result(res_fe,file_name="ndb_generic",title="generic ndb",start_from=1,period=15)
plot_result(res_fe,file_name="ndb_generic_no_cov",title="log(Generic) NDB",start_from=1,ylim=(-10,30))
# Out:
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# elapsed_m6     3.7494     4.5932     0.8163     0.4155     -5.3217      12.820
# elapsed_m5     5.0102     5.6735     0.8831     0.3785     -6.1943      16.215
# elapsed_m4     7.2101     4.3599     1.6537     0.1001     -1.4003      15.820
# elapsed_m3     7.5461     3.3802     2.2324     0.0270      0.8705      14.222
# elapsed_m2     10.631     4.0946     2.5964     0.0103      2.5447      18.717
# elapsed_0      15.683     4.4650     3.5125     0.0006      6.8654      24.501
# elapsed_1      14.453     4.2382     3.4101     0.0008      6.0825      22.823
# elapsed_2      17.815     3.0876     5.7698     0.0000      11.717      23.913
# elapsed_3      15.399     3.2941     4.6748     0.0000      8.8937      21.905
# elapsed_4      14.212     3.6345     3.9104     0.0001      7.0346      21.390
# elapsed_5      17.241     1.7468     9.8699     0.0000      13.791      20.691
# elapsed_6      17.035     1.6765     10.161     0.0000      13.724      20.346
# elapsed_7      18.589     2.0763     8.9527     0.0000      14.488      22.689
# elapsed_8      15.925     2.0630     7.7194     0.0000      11.851      19.999
# elapsed_9      13.836     1.3751     10.062     0.0000      11.120      16.552
# elapsed_10     12.640     1.0838     11.663     0.0000      10.499      14.780
# ==============================================================================

# %%
# generic with price
formula="log_quantity~elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+TimeEffects+EntityEffects"

# till elapsed_20
# formula="log_quantity~ elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+TimeEffects+EntityEffects"

# add generic_per
# formula+="+log(generic_per)"
# generic_share_r
# formula+=" + generic_share_r"
# generic_share_q
# formula+="+log(薬価)"
# formula+=" + log(generic_share_q)"
formula+="+log(price)"
# formula+="+1"
mod_fe=PanelOLS.from_formula(formula, data=df_generic,check_rank=False,drop_absorbed=True)
res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
print(res_fe.summary.tables[1])
# print(res_fe.summary.tables[0])
# print(res_fe)
# plot_result(res_fe,file_name="ndb_generic",title="generic ndb",start_from=1,period=15)
plot_result(res_fe,file_name="ndb_generic_price",title="log(Generic) NDB",start_from=1,)
# Out:
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# elapsed_m6    -0.8386     0.8796    -0.9534     0.3419     -2.5759      0.8987
# elapsed_m5    -0.3662     0.5640    -0.6493     0.5171     -1.4802      0.7477
# elapsed_m4     0.3042     0.4140     0.7349     0.4635     -0.5134      1.1218
# elapsed_m3     0.1858     0.4842     0.3838     0.7016     -0.7704      1.1420
# elapsed_m2     0.0336     0.4791     0.0701     0.9442     -0.9127      0.9798
# elapsed_0      0.4252     0.3189     1.3333     0.1844     -0.2047      1.0552
# elapsed_1      0.0587     0.6688     0.0877     0.9302     -1.2623      1.3796
# elapsed_2     -0.3129     0.5190    -0.6028     0.5475     -1.3380      0.7122
# elapsed_3     -0.1590     0.4294    -0.3703     0.7116     -1.0072      0.6891
# elapsed_4      0.7104     0.4724     1.5038     0.1346     -0.2226      1.6433
# elapsed_5      0.0955     0.4608     0.2073     0.8360     -0.8146      1.0057
# elapsed_6      0.2943     0.4075     0.7222     0.4713     -0.5105      1.0991
# elapsed_7      0.4099     0.4533     0.9043     0.3672     -0.4854      1.3053
# elapsed_8      0.2741     0.3781     0.7249     0.4696     -0.4727      1.0208
# elapsed_9     -0.1183     0.3645    -0.3246     0.7459     -0.8382      0.6016
# elapsed_10    -0.1689     0.3041    -0.5553     0.5795     -0.7695      0.4318
# log(price)     6.1588     0.0962     64.052     0.0000      5.9689      6.3487
# ==============================================================================

# %%
# brand without covariates
formula="log_quantity~ elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+TimeEffects+EntityEffects"

# till elapsed_20
# formula="log_quantity~ elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+TimeEffects+EntityEffects"
# add generic_per
# formula+="+log(generic_per)"
# formula+="+generic_per"
# generic_share_r
# formula+=" + generic_share_r"
# formula+="+elapsed_m1"
# generic_share_q
# formula+=" + log(generic_share_q)"
# formula+=" + log(薬価)"
# formula+="+log(price)"

mod_fe=PanelOLS.from_formula(formula, data=df_branded,check_rank=False,drop_absorbed=True)
res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
# print(res_fe.summary.tables[1])
# print(res_fe.summary.tables[0])
print(res_fe)
# plot_result(res_fe,file_name="ndb_brand",title="brand ndb",start_from=1,period=15)
plot_result(res_fe,file_name="ndb_brand_no_cov",title="log(Brand) NDB",ylim=(-10,30))
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           log_quantity   R-squared:                       -1958.8
# Estimator:                   PanelOLS   R-squared (Between):             -126.65
# No. Observations:                 212   R-squared (Within):              -1238.8
# Date:                Mon, Jan 22 2024   R-squared (Overall):             -139.83
# Time:                        17:59:01   Log-likelihood                   -684.15
# Cov. Estimator:             Clustered
#                                         F-statistic:                     -10.661
# Entities:                          31   P-value                           1.0000
# Avg Obs:                       6.8387   Distribution:                  F(15,160)
# Min Obs:                       3.0000
# Max Obs:                       7.0000   F-statistic (robust):             800.21
#                                         P-value                           0.0000
# Time periods:                       7   Distribution:                  F(15,160)
# Avg Obs:                       30.286
# Min Obs:                       30.000
# Max Obs:                       31.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# elapsed_m6     4.4054     4.7572     0.9260     0.3558     -4.9896      13.800
# elapsed_m5     5.4196     5.8777     0.9220     0.3579     -6.1884      17.028
# elapsed_m4     7.5956     4.5276     1.6776     0.0954     -1.3460      16.537
# elapsed_m3     7.9349     3.5206     2.2538     0.0256      0.9821      14.888
# elapsed_m2     11.183     4.2571     2.6268     0.0095      2.7752      19.590
# elapsed_0      16.407     4.7036     3.4882     0.0006      7.1181      25.696
# elapsed_1      14.973     4.4293     3.3805     0.0009      6.2256      23.721
# elapsed_2      18.615     3.2117     5.7960     0.0000      12.272      24.957
# elapsed_3      16.145     3.5031     4.6087     0.0000      9.2265      23.063
# elapsed_4      14.687     3.7959     3.8693     0.0002      7.1908      22.184
# elapsed_5      17.943     1.7982     9.9784     0.0000      14.392      21.495
# elapsed_6      17.663     1.7495     10.096     0.0000      14.208      21.118
# elapsed_7      19.310     2.1654     8.9176     0.0000      15.033      23.586
# elapsed_8      16.567     2.1150     7.8332     0.0000      12.390      20.744
# elapsed_9      14.506     1.4497     10.007     0.0000      11.643      17.369
# elapsed_10     13.130     1.1533     11.385     0.0000      10.853      15.408
# ==============================================================================
#
# F-test for Poolability: 22.371
# P-value: 0.0000
# Distribution: F(36,160)
#
# Included effects: Entity, Time

# %%
# brand with price
formula="log_quantity~ elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+TimeEffects+EntityEffects"

# till elapsed_20
# formula="log_quantity~ elapsed_m6+elapsed_m5+elapsed_m4+elapsed_m3+elapsed_m2+elapsed_0+elapsed_1+elapsed_2+elapsed_3+elapsed_4+elapsed_5+elapsed_6+elapsed_7+elapsed_8+elapsed_9+elapsed_10+elapsed_11+elapsed_12+elapsed_13+elapsed_14+elapsed_15+TimeEffects+EntityEffects"
# add generic_per
# formula+="+log(generic_per)"
# formula+="+generic_per"
# generic_share_r
# formula+=" + generic_share_r"
# formula+="+elapsed_m1"
# formula+="+1"
# generic_share_q
# formula+=" + log(generic_share_q)"
# formula+=" + log(薬価)"
formula+="+log(price)"

mod_fe=PanelOLS.from_formula(formula, data=df_branded,check_rank=False,drop_absorbed=True)
res_fe=mod_fe.fit(cov_type='clustered', cluster_entity=True)
# print(res_fe.summary.tables[1])
# print(res_fe.summary.tables[0])
print(res_fe)
# plot_result(res_fe,file_name="ndb_brand",title="brand ndb",start_from=1,period=15)
plot_result(res_fe,file_name="ndb_brand_price",title="log(Brand) NDB")
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           log_quantity   R-squared:                       -28.424
# Estimator:                   PanelOLS   R-squared (Between):             -12.311
# No. Observations:                 212   R-squared (Within):              -13.307
# Date:                Mon, Jan 22 2024   R-squared (Overall):             -10.502
# Time:                        17:59:02   Log-likelihood                   -239.08
# Cov. Estimator:             Clustered
#                                         F-statistic:                     -9.5998
# Entities:                          31   P-value                           1.0000
# Avg Obs:                       6.8387   Distribution:                  F(16,159)
# Min Obs:                       3.0000
# Max Obs:                       7.0000   F-statistic (robust):          3.723e+05
#                                         P-value                           0.0000
# Time periods:                       7   Distribution:                  F(16,159)
# Avg Obs:                       30.286
# Min Obs:                       30.000
# Max Obs:                       31.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# elapsed_m6    -0.5324     0.8076    -0.6592     0.5107     -2.1273      1.0626
# elapsed_m5    -0.4930     0.4751    -1.0376     0.3010     -1.4313      0.4454
# elapsed_m4    -0.3568     0.3297    -1.0822     0.2808     -1.0079      0.2943
# elapsed_m3    -0.4169     0.1813    -2.2996     0.0228     -0.7750     -0.0588
# elapsed_m2    -0.5603     0.2660    -2.1064     0.0367     -1.0857     -0.0350
# elapsed_0     -0.1193     0.3264    -0.3655     0.7152     -0.7639      0.5254
# elapsed_1     -0.2441     0.3929    -0.6212     0.5354     -1.0202      0.5320
# elapsed_2     -0.1646     0.5154    -0.3194     0.7498     -1.1826      0.8533
# elapsed_3      0.1371     0.4501     0.3045     0.7611     -0.7518      1.0259
# elapsed_4     -0.0493     0.4328    -0.1139     0.9095     -0.9041      0.8055
# elapsed_5     -0.1013     0.3758    -0.2695     0.7879     -0.8435      0.6410
# elapsed_6     -0.2073     0.3763    -0.5509     0.5825     -0.9505      0.5359
# elapsed_7     -0.0850     0.4014    -0.2117     0.8326     -0.8777      0.7077
# elapsed_8     -0.1252     0.2779    -0.4505     0.6530     -0.6741      0.4237
# elapsed_9      0.0564     0.2082     0.2709     0.7869     -0.3548      0.4676
# elapsed_10     0.0880     0.1471     0.5984     0.5504     -0.2025      0.3786
# log(price)     5.0212     0.0627     80.077     0.0000      4.8974      5.1451
# ==============================================================================
#
# F-test for Poolability: 307.95
# P-value: 0.0000
# Distribution: F(36,159)
#
# Included effects: Entity, Time
