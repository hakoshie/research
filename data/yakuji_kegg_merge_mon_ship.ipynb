# %%
import pandas as pd
data_ke_3=pd.read_csv("./OTC/ingre_cate_len3.csv",index_col=0)
data_ke_2=pd.read_csv("./OTC/ingre_cate_len2.csv",index_col=0)
data_yaku=pd.read_csv("./yakuji/monthly/ship_joined_monthly.csv",encoding="shift-jis",index_col=0)

# %%
data_yaku.columns
# Out:
# Index(['year', 'id', 'efficacy', 'rx_dom', 'otc_dom', 'self_dom', 'stock_rx',
#        'stock_otc', 'stock_self'],
#       dtype='object')

# %%
data_yaku.replace(' ',"0",inplace=True)
data_yaku["id"]=data_yaku["id"].astype(int)

# %%
# len 3
df_3=pd.merge(data_yaku,data_ke_3,left_on="id",right_on="id",how="left")
# sort 
df_3=df_3[df_3["id"].astype(str).str.len()==3]
df_3.sort_values(by=["year","id","Approved"]).reset_index(drop=1).to_csv("./merged/len3_ship_mon.csv",encoding="shift-jis")
df_3
# Out:
# Empty DataFrame
# Columns: [year, id, efficacy, rx_dom, otc_dom, self_dom, stock_rx, stock_otc, stock_self, Approved, KEGG, Ingredient, variable]
# Index: []

# %%
# len 2
df_2=pd.merge(data_yaku,data_ke_2,left_on="id",right_on="id",how="left")
df_2=df_2[df_2["id"].astype(str).str.len()==2]
df_2.sort_values(by=["year","id","Approved"]).reset_index(drop=1).to_csv("./merged/len2_ship_mon.csv",encoding="shift-jis")
df_2
# Out:
#          year  id    efficacy     rx_dom otc_dom  self_dom   stock_rx  \
# 1872   2009.0  10      総　　　　数  747886846  456134       0.0   90478488
# 1873   2009.0  10     中枢神経系用薬   73802960   20833       0.0   19065852
# 1874   2009.0  10       全身麻酔剤    1363172       0       0.0          0
# 1875   2009.0  10  催眠鎮静剤，抗不安剤    8511730   18103       0.0     269385
# 1876   2009.0  10      抗てんかん剤    3188628       0       0.0          0
# ...       ...  ..         ...        ...     ...       ...        ...
# 61894  2022.0  12  非アルカロイド系麻薬  1,342,142       -       0.0  2,954,920
# 61895  2022.0  12        合成麻薬  1,342,142       -       0.0  2,954,920
# 61896  2022.0  12        合成麻薬  1,342,142       -       0.0  2,954,920
# 61897  2022.0  12        合成麻薬  1,342,142       -       0.0  2,954,920
# 61898  2022.0  12        合成麻薬  1,342,142       -       0.0  2,954,920
#
#       stock_otc  stock_self  Approved    KEGG                Ingredient  \
# 1872    4682868         0.0       NaN     NaN                       NaN
# 1873    2103349         0.0       NaN     NaN                       NaN
# 1874          0         0.0       NaN     NaN                       NaN
# 1875      11700         0.0       NaN     NaN                       NaN
# 1876          0         0.0       NaN     NaN                       NaN
# ...         ...         ...       ...     ...                       ...
# 61894         -         0.0    2006.0  D01875         Tiquizium bromide
# 61895         -         0.0    1987.0  D01451  Scopolamine butylbromide
# 61896         -         0.0    1987.0  D02535        Timepidium bromide
# 61897         -         0.0    1995.0  D01152               Oxethazaine
# 61898         -         0.0    2006.0  D01875         Tiquizium bromide
#
#       variable
# 1872       NaN
# 1873       NaN
# 1874       NaN
# 1875       NaN
# 1876       NaN
# ...        ...
# 61894      id1
# 61895      id1
# 61896      id1
# 61897      id1
# 61898      id1
#
# [36581 rows x 13 columns]

# %%
# !pwd
# Out:
# /c/Users/hakos/GDrive/Downloads/Research/data
