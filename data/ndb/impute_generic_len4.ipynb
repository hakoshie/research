# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %% [markdown]
# actually no imputation is needed for len4 because it is used only for ndb event which has same year as the generic share data

# %%
data=pd.read_csv("../merged/len4_ndb_blp_DN.csv",index_col=0,encoding="shift-jis")
data.head()
# Out:
#     薬効分類   薬効分類名称       医薬品コード               医薬品名  薬価基準収載医薬品コード    薬価  後発品区分  \
# 0  114.0  解熱鎮痛消炎剤  620007096.0         ボルタレン錠２５ｍｇ  1147002F1560  13.1    0.0
# 1  114.0  解熱鎮痛消炎剤  620007095.0  ボルタレンＳＲカプセル３７．５ｍｇ  1147002N1174  23.2    0.0
# 2  114.0  解熱鎮痛消炎剤  620007096.0         ボルタレン錠２５ｍｇ  1147002F1560  13.1    0.0
# 3  114.0  解熱鎮痛消炎剤  620007095.0  ボルタレンＳＲカプセル３７．５ｍｇ  1147002N1174  23.2    0.0
# 4  114.0  解熱鎮痛消炎剤  661140081.0        ボルタレンサポ５０ｍｇ  1147700J3084  63.1    0.0
#
#              総計  year  in_hospital  ...  id_3999.0  id_4413.0  id_4490.0  \
# 0  2.489539e+07  2014            1  ...          0          0          0
# 1  1.024590e+07  2014            1  ...          0          0          0
# 2  5.025912e+07  2014            0  ...          0          0          0
# 3  2.742935e+07  2014            0  ...          0          0          0
# 4  5.339043e+06  2014            1  ...          0          0          0
#
#   id_6250.0 id_6290.0 id_7990.0   q_share   r_share generic_share_q  \
# 0         0         0         0  0.150667  0.074626        0.076961
# 1         0         0         0  0.062008  0.054392        0.076961
# 2         0         0         0  0.304168  0.150655        0.076961
# 3         0         0         0  0.166002  0.145613        0.076961
# 4         0         0         0  0.032312  0.077089        0.076961
#
#    generic_share_r
# 0         0.059379
# 1         0.059379
# 2         0.059379
# 3         0.059379
# 4         0.059379
#
# [5 rows x 107 columns]

# %%
data=data.drop_duplicates(subset=["id","year"])
# drop never treated group
data.head(),data.shape
# Out:
# (      薬効分類   薬効分類名称       医薬品コード          医薬品名  薬価基準収載医薬品コード    薬価  後発品区分  \
#  0    114.0  解熱鎮痛消炎剤  620007096.0    ボルタレン錠２５ｍｇ  1147002F1560  13.1    0.0
#  33   114.0  解熱鎮痛消炎剤  620098801.0    ロキソニン錠６０ｍｇ  1149019F1560  17.5    0.0
#  80   121.0    局所麻酔剤  620005991.0    ストロカイン錠５ｍｇ  1219002F1065   5.7    0.0
#  96   123.0    自律神経剤  620002526.0  チアトンカプセル１０ｍｇ  1231013M2179  15.2    0.0
#  147  131.0     眼科用剤  620207901.0   アダプチノール錠５ｍｇ  1319004F1035  45.9    0.0
#
#                 総計  year  in_hospital  ...  id_3999.0  id_4413.0  id_4490.0  \
#  0    2.489539e+07  2014            1  ...          0          0          0
#  33   2.654376e+08  2014            1  ...          0          0          0
#  80   1.161969e+07  2014            1  ...          0          0          0
#  96   9.128303e+06  2014            1  ...          0          0          0
#  147  5.229358e+06  2014            1  ...          0          0          0
#
#      id_6250.0 id_6290.0 id_7990.0   q_share   r_share generic_share_q  \
#  0           0         0         0  0.150667  0.074626        0.076961
#  33          0         0         0  0.081305  0.044198        0.244198
#  80          0         0         0  0.240075  0.207865        0.062114
#  96          0         0         0  0.057179  0.068222        0.129137
#  147         0         0         0  0.006420  0.001850        0.136869
#
#       generic_share_r
#  0           0.059379
#  33          0.053661
#  80          0.053451
#  96          0.064243
#  147         0.080471
#
#  [5 rows x 107 columns],
#  (256, 107))

# %%
# set(data["薬効分類"])
data.fillna(0,inplace=True)
# set(data[data["generic_share_q"].isnull()]["id"])
data[data["generic_share_q"].isnull()][["id","year"]].sort_values(by=["id","year"])
# Out:
# Empty DataFrame
# Columns: [id, year]
# Index: []

# %%
data=data.loc[:,["id","year",'generic_share_q', 'generic_share_r']]

# %%
data
# Out:
#            id  year  generic_share_q  generic_share_r
# 0      1147.0  2014         0.076961         0.059379
# 33     1149.0  2014         0.244198         0.053661
# 80     1219.0  2014         0.062114         0.053451
# 96     1231.0  2014         0.129137         0.064243
# 147    1319.0  2014         0.136869         0.080471
# ...       ...   ...              ...              ...
# 25142  4413.0  2021         0.342768         0.263456
# 25182  4490.0  2021         0.608051         0.363450
# 25386  6250.0  2021         0.502607         0.052158
# 25628  6290.0  2021         0.284349         0.073842
# 25757  7990.0  2021         0.007953         0.028184
#
# [256 rows x 4 columns]

# %%
data.to_csv("../merged/len4_ndb_generic_imputed.csv",encoding="shift-jis")
