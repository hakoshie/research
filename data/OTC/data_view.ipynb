# %%
import pandas as pd
# df=pd.read_csv("aesgp_export_20230620_all_japan_otc.csv")
df=pd.read_csv("approved_ingredients_kegg.csv")
df
# Out:
#     Approved    KEGG                 Ingredient
# 0       1983  D04269                  Soysterol
# 1       1983  D01612         Sodium picosulfate
# 2       1984  D08751   Semi-alkaline proteinase
# 3       1985  D01585                  Exalamide
# 4       1985  D01506       Dimemorfan phosphate
# ..       ...     ...                        ...
# 93      2020  D01357     Betamethasone valerate
# 94      2021  D01007  Propiverine hydrochloride
# 95      2021  D00118                   Naproxen
# 96      2021  D02729     Itopride hydrochloride
# 97      2022  D03306      Calcium polycarbophil
#
# [98 rows x 3 columns]

# %%
# df_sw=df[~df["Year of switch"].isna()]

# %%
# df_sw.sort_values("Year of switch")
# Out:
#                 Ingredient                        ATC level 1  \
# 90              Clemastine               R Respiratory system
# 25  Clotrimazole (topical)                  D Dermatologicals
# 8               Sucralfate  A Alimentary tract and metabolism
# 15    Picosulfate (sodium)  A Alimentary tract and metabolism
# 54          Indomet(h)acin          M Musculo-skeletal system
# ..                     ...                                ...
# 88             Cetirizine                R Respiratory system
# 97            Fexofenadine               R Respiratory system
# 94                Ebastine               R Respiratory system
# 0        Fluoride (sodium)  A Alimentary tract and metabolism
# 99              Loratadine               R Respiratory system
#
#                                         ATC level 2  Year of switch Country  \
# 90              R06 Antihistamines for systemic use          1979.0   Japan
# ...

# %%
# df2=pd.read_csv("switched_otc.csv",index_col=0,header=None)
# set(df2[1])
# Out:
# {'Acyclovir',
#  'Alminoprofen',
#  'Ambroxol',
#  'Amorolfine',
#  'Azelastine',
#  'Azithromycin',
#  'Beclomethasone dipropionate',
#  'Bepotastine',
#  'Betamethasone valerate',
#  'Bihonazole',
#  'Bisocodyl acetate',
#  'Bromhexine',
#  'Butenafine',
#  'Butylscopolamine',
#  'Calcium L-aspartate',
#  'Carbocisteine',
#  'Carbocysteine',
#  'Ceramide',
#  'Cetirizine',
#  'Cetirizine dihydrochloride',
#  'Ciclopirox',
#  'Ciclopirox olamine',
#  'Cimetidine',
#  'Clotrimazole (limited to vaginal candidiasis treatment)',
#  'Cromoglicic acid',
#  'Diclofenac',
#  'Dimemorfan',
#  'Ebastine',
#  'Econazole',
#  'Emedastine',
#  'Epinastine',
#  'Epinoside',
#  'Ethyl eicosapentaenoic acid',
#  'Famotidine',
#  'Felbinac',
#  'Fexofenadine',
#  'Flavoxate',
#  'Flunisolide',
#  'Fluticasone propionate',
#  'Gefarnate',
#  'Heparnicate',
#  'Hydrocortisone butyrate',
#  'Ibuprofen',
#  'Ibuprofen piconol',
#  'Indomethacin',
# ...

# %%
db_set=set(df["Ingredient"])
cnt=0
for x in df2[1]:
    if x in db_set:
        cnt+=1
        print(x,cnt)
# Out:
# Azelastine 1
# Ambroxol 2
# Carbocisteine 3
# Ebastine 4
# Oxiconazole 5
# Oxymetazoline 6
# Cromoglicic acid 7
# Ketotifen 8
# Cimetidine 9
# Dimemorfan 10
# Terbinafine 11
# Nizatidine 12
# Famotidine 13
# Fexofenadine 14
# Butenafine 15
# Bromhexine 16
# Ubidecarenone 17
# Ranitidine 18
# Loperamide 19
# Loratadine 20
