# %%
import pandas as pd
import requests
import time
# CSVファイルの読み込み
df = pd.read_csv('kegg_with_category.csv',encoding="shift-jis",index_col=0)

# %%
cse_id="a237152e541844b88"
api_key="AIzaSyDLd9vn0ZE5AgRW6Q_WFQDlSx2TEmOy52k"
# クエリを生成し、検索結果を取得

# Send a request to Google CSE
# url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&cx={cse_id}&q={query}"
# response = requests.get(url)

# Replace 'YOUR_CSE_ID' with your actual CSE ID
# cse_id = 'YOUR_CSE_ID'

# Initialize an empty list to store search results
search_results = []

# Loop through the CSV data and perform searches
for i,row in enumerate(df.itertuples()):
    query = row.成分+" 発売日 スイッチOTC 新発売 日本初"  # Replace 'Query' with the actual column name in your CSV
    year=row.Approved
    id=row.id
    url= f"https://www.google.co.jp/search?q={query}"
    url2= f"https://www.google.co.jp/search?q={query}&tbs=cdr:1,cd_max:12/31/{year}"
    # if i>5:
    #     break
    # Send a request to Google CSE
 
    search_results.append((id,year,row.KEGG,url,url2,query))
 

# Now, search_results contains the search results for each query in your CSV

# %%
# for i,x in enumerate(search_results):
#     print(x[0],i)

# %%
result_df=pd.DataFrame()
result_dicts=[]
# i=0
for id,year,KEGG,url,url2,query in search_results:
    print(id,i)
    # i+=1

        # print(k)
    result_dicts.append({
        "id": id,  
        "year":year,
        "KEGG":KEGG,
        "url":url,
        "url2":url2,
        "Query": query,

    })
result_df = pd.DataFrame(result_dicts)
# Out:
# nan 97
# 2359 97
# nan 97
# nan 97
# 2229 97
# 1145 2649 97
# 1149 97
# 2189 3919 97
# nan 97
# 1242 97
# 2234 97
# 2329 97
# 1249 97
# nan 97
# 2529 2655 97
# nan 97
# nan 97
# nan 97
# nan 97
# 2172 97
# 2319 97
# 2119 97
# 2646 97
# 4413 97
# nan 97
# 2649 97
# nan 97
# 2649 97
# 2249 97
# nan 97
# 3136 97
# 2646 97
# 3214 97
# 2655 97
# 2655 97
# 2529 2655 97
# 1149 2649 97
# 1149 2649 97
# 1219 97
# 2399 97
# 2649 97
# 2329 97
# 1319 1329 2259 4490 97
# 2325 97
# 2325 97
# nan 97
# 2329 97
# nan 97
# 2329 97
# 7990 97
# 2659 97
# 2659 97
# 2655 97
# 1149 1319 97
# 2659 6290 97
# 2325 97
# 2325 97
# 1319 1329 4490 97
# 4490 97
# 3992 97
# 1231 97
# 2655 97
# 1319 2399 2454 2646 97
# 1319 6250 97
# 2239 97
# 3327 4490 97
# 2529 2655 97
# 4490 97
# 2590 97
# 1147 1319 2649 97
# 6250 97
# 1149 2649 97
# 1319 4490 97
# 2329 97
# 1329 2290 2459 97
# 2529 2655 6290 97
# 1324 97
# 1319 97
# 1319 4490 97
# 4490 97
# 2189 3399 97
# 4490 97
# 1319 4490 97
# 4490 97
# 1149 97
# nan 97
# 2790 97
# 4490 97
# 4490 97
# 1329 97
# 1329 2290 97
# 1319 3999 97
# nan 97
# 2646 97
# 2590 97
# 1149 97
# 2399 97
# 2399 97

# %%
result_df.shape
# result_df.replace("\xa0","",regex=True,inplace=True)
# result_df.to_csv("search_result.csv",encoding="shift-jis")
# Out:
# (98, 6)

# %%
from openpyxl import Workbook
from openpyxl.worksheet.hyperlink import Hyperlink
# result_df = pd.DataFrame(result_dicts)

# Create a new Excel workbook
wb = Workbook()

# Create a new Excel sheet
ws = wb.active

# Add column headers to the sheet
column_names = result_df.columns.tolist()
ws.append(column_names)

# Make the URLs in the "Link" column clickable hyperlinks
# Make the URLs in the "Link" column clickable hyperlinks
for _, row in result_df.iterrows():
    # print(row)
    ws.append([row['id'],row["year"],row['KEGG'],row["url"],row["url2"],row['Query']])

target_columns = ["url","url2"]  # ハイパーリンクを設定したい列名を指定

for column_name in target_columns:
    column_index = column_names.index(column_name) + 1  # 列名から列のインデックスを取得

    for row in ws.iter_rows(min_row=2, max_row=ws.max_row, min_col=column_index, max_col=column_index):
        for cell in row:
            cell.hyperlink = cell.value

# Save the workbook to an Excel file
output_file = 'G_hyperlinks.xlsx'  # Specify the desired output file name
wb.save(output_file)

print(f"Search results with hyperlinks saved to {output_file}")
# Out:
# Search results with hyperlinks saved to G_hyperlinks.xlsx
