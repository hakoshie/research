# %%
import pandas as pd
data=pd.read_csv("kegg_with_category.csv",index_col=0,encoding="shift-jis")
data
# Out:
#     Approved    KEGG                 Ingredient    id                 成分  \
# 0       1983  D04269                  Soysterol   NaN  ソイステロール(大豆油不けん化物）
# 1       1983  D01612         Sodium picosulfate  2359      ピコスルファートナトリウム
# 2       1984  D08751   Semi-alkaline proteinase   NaN      セミアルカリプロティナーゼ
# 3       1985  D01585                  Exalamide   NaN             エキサラミド
# 4       1985  D01506       Dimemorfan phosphate  2229        ジメモルファンリン酸塩
# ..       ...     ...                        ...   ...                ...
# 93      2020  D01357     Betamethasone valerate  2646      ベタメタゾン吉草酸エステル
# 94      2021  D01007  Propiverine hydrochloride  2590          プロピベリン塩酸塩
# 95      2021  D00118                   Naproxen  1149             ナプロキセン
# 96      2021  D02729     Itopride hydrochloride  2399           イトプリド塩酸塩
# 97      2022  D03306      Calcium polycarbophil  2399      ポリカルボフィルカルシウム
#
#           date                                                url
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# ..         ...                                                ...
# 93  2021/02/16  https://prtimes.jp/main/html/rd/p/000000015.00...
# 94  2021/11/24  https://www.taiho.co.jp/release/2021/20211124....
# 95         NaN                                                NaN
# 96  2022/09/28  https://prtimes.jp/main/html/rd/p/000000056.00...
# 97         NaN                                                NaN
#
# [98 rows x 7 columns]

# %%
for i,ids in enumerate(data["id"]):
    if type(ids)==str:
        split_ids=ids.split()
        for j, id in enumerate(split_ids):
            column_name =f"id{j+1}"
            if column_name not in data.columns:
                data[column_name]=""
            data.at[i,column_name]=id

# %%
data
# Out:
#     Approved    KEGG                 Ingredient    id                 成分  \
# 0       1983  D04269                  Soysterol   NaN  ソイステロール(大豆油不けん化物）
# 1       1983  D01612         Sodium picosulfate  2359      ピコスルファートナトリウム
# 2       1984  D08751   Semi-alkaline proteinase   NaN      セミアルカリプロティナーゼ
# 3       1985  D01585                  Exalamide   NaN             エキサラミド
# 4       1985  D01506       Dimemorfan phosphate  2229        ジメモルファンリン酸塩
# ..       ...     ...                        ...   ...                ...
# 93      2020  D01357     Betamethasone valerate  2646      ベタメタゾン吉草酸エステル
# 94      2021  D01007  Propiverine hydrochloride  2590          プロピベリン塩酸塩
# 95      2021  D00118                   Naproxen  1149             ナプロキセン
# 96      2021  D02729     Itopride hydrochloride  2399           イトプリド塩酸塩
# 97      2022  D03306      Calcium polycarbophil  2399      ポリカルボフィルカルシウム
#
#           date                                                url   id1 id2  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN  2359
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN  2229
# ..         ...                                                ...   ...  ..
# 93  2021/02/16  https://prtimes.jp/main/html/rd/p/000000015.00...  2646
# 94  2021/11/24  https://www.taiho.co.jp/release/2021/20211124....  2590
# 95         NaN                                                NaN  1149
# 96  2022/09/28  https://prtimes.jp/main/html/rd/p/000000056.00...  2399
# 97         NaN                                                NaN  2399
#
#    id3 id4
# 0
# 1
# 2
# 3
# 4
# ..  ..  ..
# 93
# 94
# 95
# 96
# 97
#
# [98 rows x 11 columns]

# %%
data=data.drop("id",axis=1)

# %%
data
# Out:
#     Approved    KEGG                 Ingredient                 成分  \
# 0       1983  D04269                  Soysterol  ソイステロール(大豆油不けん化物）
# 1       1983  D01612         Sodium picosulfate      ピコスルファートナトリウム
# 2       1984  D08751   Semi-alkaline proteinase      セミアルカリプロティナーゼ
# 3       1985  D01585                  Exalamide             エキサラミド
# 4       1985  D01506       Dimemorfan phosphate        ジメモルファンリン酸塩
# ..       ...     ...                        ...                ...
# 93      2020  D01357     Betamethasone valerate      ベタメタゾン吉草酸エステル
# 94      2021  D01007  Propiverine hydrochloride          プロピベリン塩酸塩
# 95      2021  D00118                   Naproxen             ナプロキセン
# 96      2021  D02729     Itopride hydrochloride           イトプリド塩酸塩
# 97      2022  D03306      Calcium polycarbophil      ポリカルボフィルカルシウム
#
#           date                                                url   id1 id2  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN  2359
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN  2229
# ..         ...                                                ...   ...  ..
# 93  2021/02/16  https://prtimes.jp/main/html/rd/p/000000015.00...  2646
# 94  2021/11/24  https://www.taiho.co.jp/release/2021/20211124....  2590
# 95         NaN                                                NaN  1149
# 96  2022/09/28  https://prtimes.jp/main/html/rd/p/000000056.00...  2399
# 97         NaN                                                NaN  2399
#
#    id3 id4
# 0
# 1
# 2
# 3
# 4
# ..  ..  ..
# 93
# 94
# 95
# 96
# 97
#
# [98 rows x 10 columns]

# %%
data.to_csv("kegg_w_cate_split.csv")
