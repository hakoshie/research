# %%
relation_map = {
    "総合ビタミン剤": ["総合感冒剤", "その他のビタミン剤"],
    "ビタミンＢ１剤": ["ビタミンＢ剤（ビタミンＢ１剤を除く。）", "ビタミンＢ１剤"],
    "総合感冒薬": ["総合感冒剤", "その他の医薬品"],
    "鼻炎治療剤": ["耳鼻科用剤"],
    "アレルギー用薬": ["抗ヒスタミン剤", "その他のアレルギー用薬"],
    "解熱鎮痛剤": ["解熱鎮痛消炎剤"],
    "鎮咳去痰剤": ["鎮咳剤"],
    "胃腸薬": ["複合胃腸剤", "健胃消化剤"],
    "整腸薬": ["止しゃ剤，整腸剤"],
    "便秘薬": ["下剤，浣腸剤"],
    "その他消化器官系薬": ["その他の消化器官用薬"],
    "外用鎮痛・消炎剤": ["その他の外皮用薬"],
    "皮膚用薬（除殺菌）": ["その他の外皮用薬"],
    "水虫治療薬": ["その他の外皮用薬"],
    "目薬": ["眼科用剤"],
    "その他感覚器官外皮": ["その他の外皮用薬"],
    "強心剤": ["強心剤"],
    "禁煙補助剤": ["他に分類されない治療を主目的としない医薬品"],
    "その他の医薬品": ["その他の医薬品"],
    # 他の薬効分類タイプAとタイプBの関連付けを追加
}
{
    '総合ビタミン剤': 312,
    'ビタミンＢ１剤': 312,
    '総合感冒薬': 118,
    '鼻炎治療剤': 132,
    'アレルギー用薬': 449,
    '解熱鎮痛剤': 114,
    '鎮咳去痰剤': 222,
    '胃腸薬': 237,
    '整腸薬': 231,
    '便秘薬': 235,
    'その他消化器官系薬': 239,
    '外用鎮痛・消炎剤': 269,
    '皮膚用薬（除殺菌）': 269,
    '水虫治療薬': 265,
    '目薬': 131,
    'その他感覚器官外皮': 269,
    '強心剤': 211,
    '禁煙補助剤': 799,
    'その他の医薬品': 617
}
