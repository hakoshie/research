# %%
import pandas as pd
data_ke_3=pd.read_csv("./OTC/ingre_cate_len3.csv",index_col=0)
data_ke_2=pd.read_csv("./OTC/ingre_cate_len2.csv",index_col=0)
data_yaku=pd.read_csv("./yakuji/data_ship_whole.csv",encoding="shift-jis")

# %%
merged_df=pd.merge(data_yaku,data_ke_3,left_on="id",right_on="id1",how="left")
merged_df=pd.merge(merged_df,data_ke_3,left_on="id",right_on="id2",how="left")
merged_df=pd.merge(merged_df,data_ke_3,left_on="id",right_on="id3",how="left")
merged_df=pd.merge(merged_df,data_ke_3,left_on="id",right_on="id4",how="left")
merged_df.to_csv("tmp.csv")
merged_df
# Out:
# C:\Users\hakos\AppData\Local\Temp\ipykernel_13820\440809955.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'id4_x', 'Approved_x', 'id3_x', 'KEGG_x', 'id1_x', 'Ingredient_x', 'id2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df=pd.merge(merged_df,data_ke_3,left_on="id",right_on="id4",how="left")
#       year   id   efficacy     rx_dom    otc_dom  self_dom   stock_rx  \
# 0     2011   11    中枢神経系用薬  898429962   95865869         0  124639933
# 1     2011   44    アレルギー用薬  378834447    2611533         0   33444935
# 2     2011  441    抗ヒスタミン剤    5580612    1247574         0     924056
# 3     2011  442      刺激療法剤    4720928          0         0     181579
# 4     2011  443  非特異性免疫原製剤          0          0         0          0
# ...    ...  ...        ...        ...        ...       ...        ...
# 3577  2021   26       外皮用薬  242442964  157209011  46244232   41748859
# ...

# %%
# !pwd
# Out:
# /c/Users/hakos/gdrive/Downloads/Research/data
