# %%
import pandas as pd
data_ke_3=pd.read_csv("./OTC/ingre_cate_len3.csv",index_col=0)
data_ke_2=pd.read_csv("./OTC/ingre_cate_len2.csv",index_col=0)
data_yaku=pd.read_csv("./yakuji/monthly/prod_joined_monthly.csv",encoding="shift-jis",index_col=0)

# %%
data_yaku.columns
# Out:
# Index(['year', 'month', 'id', 'efficacy', 'rx_agg', 'rx_pro_agg', 'rx_pro_dom',
#        'otc_agg', 'otc_pro_agg', 'otc_pro_dom', 'self_agg', 'self_pro_agg',
#        'self_pro_dom'],
#       dtype='object')

# %%
data_yaku.replace(' ',"0",inplace=True)
data_yaku["id"]=data_yaku["id"].astype(int) 
data_yaku['month'] = data_yaku['month'].astype(int)
data_yaku['year'] = data_yaku['year'].astype(int)
data_yaku['year_month'] = data_yaku.apply(lambda row: f"{row['year']}-{row['month']:02d}", axis=1)

# %%
# len 3
df_3=pd.merge(data_yaku,data_ke_3,left_on="id",right_on="id",how="left")
# sort 
df_3=df_3[df_3["id"].astype(str).str.len()==3]
df_3.sort_values(by=["year","id","Approved"]).reset_index(drop=1).to_csv("./merged/len3_prod_mon.csv",encoding="shift-jis")
df_3
# Out:
#        year  month   id               efficacy     rx_agg rx_pro_agg  \
# 2      2009      1  111                  全身麻酔剤    1341311     596054
# 3      2009      1  112             催眠鎮静剤，抗不安剤    6526356    5458099
# 4      2009      1  113                 抗てんかん剤    2528330    2528330
# 5      2009      1  114                解熱鎮痛消炎剤    9749959    9528474
# 6      2009      1  114                解熱鎮痛消炎剤    9749959    9528474
# ...     ...    ...  ...                    ...        ...        ...
# 47495  2023      4  749           その他の体外診断用医薬品          -          -
# 47497  2023      4  799  他に分類されない治療を主目的としない医薬品  1,297,493  1,297,493
# 47499  2023      4  811           あへんアルカロイド系麻薬  1,535,740  1,535,740
# 47500  2023      4  812            コカアルカロイド系製剤          -          -
# 47502  2023      4  821                   合成麻薬  1,754,142  1,257,243
#
#       rx_pro_dom  otc_agg otc_pro_agg otc_pro_dom  self_agg  self_pro_agg  \
# 2         596054        0           0           0       0.0           0.0
# 3        1438569   186967      178591        8376       0.0           0.0
# 4        1762856    12624       12624           0       0.0           0.0
# 5        6804286  1328236     1328236           0       0.0           0.0
# 6        6804286  1328236     1328236           0       0.0           0.0
# ...          ...      ...         ...         ...       ...           ...
# 47495          -        -           -           -       0.0           0.0
# 47497    726,596  576,769     179,548           -       0.0           0.0
# 47499  1,535,740        -           -           -       0.0           0.0
# 47500          -        -           -           -       0.0           0.0
# 47502    540,525        -           -           -       0.0           0.0
#
#        self_pro_dom year_month  Approved    KEGG   Ingredient variable
# 2               0.0    2009-01       NaN     NaN          NaN      NaN
# 3               0.0    2009-01       NaN     NaN          NaN      NaN
# 4               0.0    2009-01       NaN     NaN          NaN      NaN
# 5               0.0    2009-01    1985.0  D00141  Indometacin      id1
# 6               0.0    2009-01    1985.0  D00126    Ibuprofen      id1
# ...             ...        ...       ...     ...          ...      ...
# 47495           0.0    2023-04       NaN     NaN          NaN      NaN
# 47497           0.0    2023-04    2001.0  D03365     Nicotine      id1
# 47499           0.0    2023-04       NaN     NaN          NaN      NaN
# 47500           0.0    2023-04       NaN     NaN          NaN      NaN
# 47502           0.0    2023-04       NaN     NaN          NaN      NaN
#
# [41140 rows x 18 columns]

# %%
# len 2
df_2=pd.merge(data_yaku,data_ke_2,left_on="id",right_on="id",how="left")
df_2=df_2[df_2["id"].astype(str).str.len()==2]
df_2.sort_values(by=["year","id","Approved"]).reset_index(drop=1).to_csv("./merged/len2_prod_mon.csv",encoding="shift-jis")
df_2
# Out:
#        year  month  id            efficacy     rx_agg rx_pro_agg rx_pro_dom  \
# 1      2009      1  11             中枢神経系用薬   53505512   42488269   28835520
# 2      2009      1  11             中枢神経系用薬   53505512   42488269   28835520
# 3      2009      1  11             中枢神経系用薬   53505512   42488269   28835520
# 4      2009      1  11             中枢神経系用薬   53505512   42488269   28835520
# 5      2009      1  11             中枢神経系用薬   53505512   42488269   28835520
# ...     ...    ...  ..                 ...        ...        ...        ...
# 49647  2023      4  72  診断用薬（体外診断用医薬品を除く。）  5,858,072  3,036,355    544,038
# 49651  2023      4  73              公衆衛生用薬    680,337    680,337    310,919
# 49664  2023      4  79   その他の治療を主目的としない医薬品  1,297,493  1,297,493    726,596
# 49666  2023      4  81     アルカロイド系麻薬（天然麻薬）  1,535,740  1,535,740  1,535,740
# 49669  2023      4  82          非アルカロイド系麻薬  1,754,142  1,257,243    540,525
#
#          otc_agg otc_pro_agg otc_pro_dom  self_agg  self_pro_agg  \
# 1        3326776     3300439       26337       0.0           0.0
# 2        3326776     3300439       26337       0.0           0.0
# 3        3326776     3300439       26337       0.0           0.0
# 4        3326776     3300439       26337       0.0           0.0
# 5        3326776     3300439       26337       0.0           0.0
# ...          ...         ...         ...       ...           ...
# 49647          -           -           -       0.0           0.0
# 49651  1,431,176   1,424,896   1,098,078       0.0           0.0
# 49664    576,769     179,548           -       0.0           0.0
# 49666          -           -           -       0.0           0.0
# 49669          -           -           -       0.0           0.0
#
#        self_pro_dom year_month  Approved    KEGG   Ingredient variable
# 1               0.0    2009-01    1985.0  D00141  Indometacin      id1
# 2               0.0    2009-01    1985.0  D00126    Ibuprofen      id1
# 3               0.0    2009-01    1994.0  D00127    Piroxicam      id1
# 4               0.0    2009-01    1994.0  D00132   Ketoprofen      id1
# 5               0.0    2009-01    2002.0  D01578  Pranoprofen      id1
# ...             ...        ...       ...     ...          ...      ...
# 49647           0.0    2023-04       NaN     NaN          NaN      NaN
# 49651           0.0    2023-04       NaN     NaN          NaN      NaN
# 49664           0.0    2023-04    2001.0  D03365     Nicotine      id1
# 49666           0.0    2023-04       NaN     NaN          NaN      NaN
# 49669           0.0    2023-04       NaN     NaN          NaN      NaN
#
# [21398 rows x 18 columns]

# %%
# !pwd
# Out:
# /c/Users/hakos/GDrive/Downloads/Research/data
