# %%
import pandas as pd
import os
os.chdir("../")

data_ke_3=pd.read_csv("./OTC/ingre_cate_len3.csv",index_col=0)
data_ke_2=pd.read_csv("./OTC/ingre_cate_len2.csv",index_col=0)
data_yaku=pd.read_csv("./yakuji/monthly/ship_joined_monthly.csv",encoding="shift-jis",index_col=0)

# %%
data_yaku.columns
# Out:
# Index(['year', 'month', 'id', 'efficacy', 'rx_dom', 'otc_dom', 'self_dom',
#        'stock_rx', 'stock_otc', 'stock_self'],
#       dtype='object')

# %%
data_yaku.replace(' ',"0",inplace=True)
data_yaku.replace(',','',inplace=True,regex=True)
data_yaku["id"]=data_yaku["id"].astype(int) 
# Combine year and month columns into a new column named "year_month"
data_yaku['month'] = data_yaku['month'].astype(int)
data_yaku['year'] = data_yaku['year'].astype(int)
data_yaku['year_month'] = data_yaku.apply(lambda row: f"{row['year']}-{row['month']:02d}", axis=1)

# %%
# for x in data_yaku.groupby(["id"])["stock_rx","year","month"]:
#     print(x)

# %%
# make lag columns only for shipment
for col in ['stock_rx','stock_otc', 'stock_self']:
    print(col)
    data_yaku[f'{col}_lag']=data_yaku.groupby(["id"])[col].shift()
# Out:
# stock_rx
# stock_otc
# stock_self

# %%
# len 3
df_3=pd.merge(data_yaku,data_ke_3,left_on="id",right_on="id",how="left")
# sort 
df_3=df_3[df_3["id"].astype(str).str.len()==3]
df_3.sort_values(by=["year","id","Approved"]).reset_index(drop=1).to_csv("./merged/len3_ship_mon.csv",encoding="shift-jis")
df_3
# Out:
#        year  month   id               efficacy   rx_dom otc_dom  self_dom  \
# 2      2009      1  111                  全身麻酔剤  1188944       0       0.0
# 3      2009      1  112             催眠鎮静剤，抗不安剤  6403591   12313       0.0
# 4      2009      1  113                 抗てんかん剤  2550122       0       0.0
# 5      2009      1  114                解熱鎮痛消炎剤  9028279       0       0.0
# 6      2009      1  114                解熱鎮痛消炎剤  9028279       0       0.0
# ...     ...    ...  ...                    ...      ...     ...       ...
# 47394  2023      4  749           その他の体外診断用医薬品     4777       -       0.0
# 47396  2023      4  799  他に分類されない治療を主目的としない医薬品  1538569  533284       0.0
# 47398  2023      4  811           あへんアルカロイド系麻薬  1356678       -       0.0
# 47399  2023      4  812            コカアルカロイド系製剤        -       -       0.0
# 47401  2023      4  821                   合成麻薬  1349824       -       0.0
#
#       stock_rx stock_otc  stock_self year_month stock_rx_lag stock_otc_lag  \
# 2            0         0         0.0    2009-01          NaN           NaN
# 3       361285      6993         0.0    2009-01          NaN           NaN
# 4            0         0         0.0    2009-01          NaN           NaN
# 5      2390534    281726         0.0    2009-01          NaN           NaN
# 6      2390534    281726         0.0    2009-01          NaN           NaN
# ...        ...       ...         ...        ...          ...           ...
# 47394    41404         -         0.0    2023-04        46181             -
# 47396  1282701    214219         0.0    2023-04      1497563        170752
# 47398  6831921         -         0.0    2023-04      6667411             -
# 47399        -         -         0.0    2023-04            -             -
# 47401  2972266         -         0.0    2023-04      2503324             -
#
#        stock_self_lag  Approved    KEGG   Ingredient variable
# 2                 NaN       NaN     NaN          NaN      NaN
# 3                 NaN       NaN     NaN          NaN      NaN
# 4                 NaN       NaN     NaN          NaN      NaN
# 5                 NaN    1985.0  D00141  Indometacin      id1
# 6                 NaN    1985.0  D00126    Ibuprofen      id1
# ...               ...       ...     ...          ...      ...
# 47394             0.0       NaN     NaN          NaN      NaN
# 47396             0.0    2001.0  D03365     Nicotine      id1
# 47398             0.0       NaN     NaN          NaN      NaN
# 47399             0.0       NaN     NaN          NaN      NaN
# 47401             0.0       NaN     NaN          NaN      NaN
#
# [41100 rows x 18 columns]

# %%
# len 2
df_2=pd.merge(data_yaku,data_ke_2,left_on="id",right_on="id",how="left")
df_2=df_2[df_2["id"].astype(str).str.len()==2]
df_2.sort_values(by=["year","id","Approved"]).reset_index(drop=1).to_csv("./merged/len2_ship_mon.csv",encoding="shift-jis")
df_2
# Out:
#        year  month  id            efficacy    rx_dom  otc_dom  self_dom  \
# 1      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 2      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 3      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 4      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 5      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# ...     ...    ...  ..                 ...       ...      ...       ...
# 49392  2023      4  72  診断用薬（体外診断用医薬品を除く。）   7276493        -       0.0
# 49396  2023      4  73              公衆衛生用薬    668810  1214674       0.0
# 49409  2023      4  79   その他の治療を主目的としない医薬品   1538569   533284       0.0
# 49411  2023      4  81     アルカロイド系麻薬（天然麻薬）   1356678        -       0.0
# 49414  2023      4  82          非アルカロイド系麻薬   1349824        -       0.0
#
#        stock_rx stock_otc  stock_self year_month stock_rx_lag stock_otc_lag  \
# 1      15675196   1513406         0.0    2009-01          NaN           NaN
# 2      15675196   1513406         0.0    2009-01          NaN           NaN
# 3      15675196   1513406         0.0    2009-01          NaN           NaN
# 4      15675196   1513406         0.0    2009-01          NaN           NaN
# 5      15675196   1513406         0.0    2009-01          NaN           NaN
# ...         ...       ...         ...        ...          ...           ...
# 49392  14240461         -         0.0    2023-04     15381632             -
# 49396    749811   6465972         0.0    2023-04       712843       6771517
# 49409   1282701    214219         0.0    2023-04      1497563        170752
# 49411   6831921         -         0.0    2023-04      6667411             -
# 49414   2972266         -         0.0    2023-04      2503324             -
#
#        stock_self_lag  Approved    KEGG   Ingredient variable
# 1                 NaN    1985.0  D00141  Indometacin      id1
# 2                 NaN    1985.0  D00126    Ibuprofen      id1
# 3                 NaN    1994.0  D00127    Piroxicam      id1
# 4                 NaN    1994.0  D00132   Ketoprofen      id1
# 5                 NaN    2002.0  D01578  Pranoprofen      id1
# ...               ...       ...     ...          ...      ...
# 49392             0.0       NaN     NaN          NaN      NaN
# 49396             0.0       NaN     NaN          NaN      NaN
# 49409             0.0    2001.0  D03365     Nicotine      id1
# 49411             0.0       NaN     NaN          NaN      NaN
# 49414             0.0       NaN     NaN          NaN      NaN
#
# [21100 rows x 18 columns]

# %%
# !pwd
# Out:
# /c/Users/hakos/GDrive/Downloads/Research/data
