# %%
import pandas as pd
import os
# os.chdir("../")

data_ke_3=pd.read_csv("../OTC/ingre_cate_len3.csv",index_col=0,encoding="shift-jis")
data_ke_2=pd.read_csv("../OTC/ingre_cate_len2.csv",index_col=0,encoding="shift-jis")
data_yaku=pd.read_csv("../yakuji/monthly/ship_joined_monthly.csv",encoding="shift-jis",index_col=0)

# %%
data_yaku.columns
# Out:
# Index(['year', 'month', 'id', 'efficacy', 'rx_dom', 'otc_dom', 'self_dom',
#        'stock_rx', 'stock_otc', 'stock_self'],
#       dtype='object')

# %%
data_yaku.replace(' ',"0",inplace=True)
data_yaku.replace(',','',inplace=True,regex=True)
data_yaku["id"]=data_yaku["id"].astype(int) 
# Combine year and month columns into a new column named "year_month"
data_yaku['month'] = data_yaku['month'].astype(int)
data_yaku['year'] = data_yaku['year'].astype(int)
data_yaku['year_month'] = data_yaku.apply(lambda row: f"{row['year']}-{row['month']:02d}", axis=1)

# %%
# for x in data_yaku.groupby(["id"])["stock_rx","year","month"]:
#     print(x)

# %%
# make lag columns only for shipment
for col in ['stock_rx','stock_otc', 'stock_self']:
    print(col)
    data_yaku[f'{col}_lag']=data_yaku.groupby(["id"])[col].shift()
# Out:
# stock_rx
# stock_otc
# stock_self

# %%
# len 3
df_3=pd.merge(data_yaku,data_ke_3,left_on="id",right_on="id",how="left")
# sort 
df_3=df_3[df_3["id"].astype(str).str.len()==3]
df_3.sort_values(by=["year","id","release_year"]).reset_index(drop=1).to_csv("../merged/len3_ship_mon.csv",encoding="shift-jis")
df_3
# Out:
#        year  month   id               efficacy   rx_dom otc_dom  self_dom  \
# 2      2009      1  111                  全身麻酔剤  1188944       0       0.0
# 3      2009      1  112             催眠鎮静剤，抗不安剤  6403591   12313       0.0
# 4      2009      1  113                 抗てんかん剤  2550122       0       0.0
# 5      2009      1  114                解熱鎮痛消炎剤  9028279       0       0.0
# 6      2009      1  114                解熱鎮痛消炎剤  9028279       0       0.0
# ...     ...    ...  ...                    ...      ...     ...       ...
# 46030  2023      4  749           その他の体外診断用医薬品     4777       -       0.0
# 46032  2023      4  799  他に分類されない治療を主目的としない医薬品  1538569  533284       0.0
# 46034  2023      4  811           あへんアルカロイド系麻薬  1356678       -       0.0
# 46035  2023      4  812            コカアルカロイド系製剤        -       -       0.0
# 46037  2023      4  821                   合成麻薬  1349824       -       0.0
#
#       stock_rx stock_otc  stock_self  ... stock_rx_lag stock_otc_lag  \
# 2            0         0         0.0  ...          NaN           NaN
# 3       361285      6993         0.0  ...          NaN           NaN
# 4            0         0         0.0  ...          NaN           NaN
# 5      2390534    281726         0.0  ...          NaN           NaN
# 6      2390534    281726         0.0  ...          NaN           NaN
# ...        ...       ...         ...  ...          ...           ...
# 46030    41404         -         0.0  ...        46181             -
# 46032  1282701    214219         0.0  ...      1497563        170752
# 46034  6831921         -         0.0  ...      6667411             -
# 46035        -         -         0.0  ...            -             -
# 46037  2972266         -         0.0  ...      2503324             -
#
#       stock_self_lag  Approved    KEGG  Ingredient       date release_year  \
# 2                NaN       NaN     NaN         NaN        NaN          NaN
# 3                NaN       NaN     NaN         NaN        NaN          NaN
# 4                NaN       NaN     NaN         NaN        NaN          NaN
# 5                NaN    1994.0  D00127   Piroxicam  1995/1/24       1995.0
# 6                NaN    1994.0  D00132  Ketoprofen  1995/2/10       1995.0
# ...              ...       ...     ...         ...        ...          ...
# 46030            0.0       NaN     NaN         NaN        NaN          NaN
# 46032            0.0    2001.0  D03365    Nicotine  2001/9/10       2001.0
# 46034            0.0       NaN     NaN         NaN        NaN          NaN
# 46035            0.0       NaN     NaN         NaN        NaN          NaN
# 46037            0.0       NaN     NaN         NaN        NaN          NaN
#
#             成分 variable
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN
# 5       ピロキシカム      id1
# 6      ケトプロフェン      id1
# ...        ...      ...
# 46030      NaN      NaN
# 46032     ニコチン      id1
# 46034      NaN      NaN
# 46035      NaN      NaN
# 46037      NaN      NaN
#
# [39736 rows x 21 columns]

# %%
# len 2
df_2=pd.merge(data_yaku,data_ke_2,left_on="id",right_on="id",how="left")
df_2=df_2[df_2["id"].astype(str).str.len()==2]
df_2.sort_values(by=["year","id","release_year"]).reset_index(drop=1).to_csv("../merged/len2_ship_mon.csv",encoding="shift-jis")
df_2
# Out:
#        year  month  id            efficacy    rx_dom  otc_dom  self_dom  \
# 1      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 2      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 3      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 4      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# 5      2009      1  11             中枢神経系用薬  52007840    12625       0.0
# ...     ...    ...  ..                 ...       ...      ...       ...
# 47062  2023      4  72  診断用薬（体外診断用医薬品を除く。）   7276493        -       0.0
# 47066  2023      4  73              公衆衛生用薬    668810  1214674       0.0
# 47079  2023      4  79   その他の治療を主目的としない医薬品   1538569   533284       0.0
# 47081  2023      4  81     アルカロイド系麻薬（天然麻薬）   1356678        -       0.0
# 47084  2023      4  82          非アルカロイド系麻薬   1349824        -       0.0
#
#        stock_rx stock_otc  stock_self  ... stock_rx_lag stock_otc_lag  \
# 1      15675196   1513406         0.0  ...          NaN           NaN
# 2      15675196   1513406         0.0  ...          NaN           NaN
# 3      15675196   1513406         0.0  ...          NaN           NaN
# 4      15675196   1513406         0.0  ...          NaN           NaN
# 5      15675196   1513406         0.0  ...          NaN           NaN
# ...         ...       ...         ...  ...          ...           ...
# 47062  14240461         -         0.0  ...     15381632             -
# 47066    749811   6465972         0.0  ...       712843       6771517
# 47079   1282701    214219         0.0  ...      1497563        170752
# 47081   6831921         -         0.0  ...      6667411             -
# 47084   2972266         -         0.0  ...      2503324             -
#
#       stock_self_lag  Approved    KEGG                 Ingredient       date  \
# 1                NaN    1994.0  D00127                  Piroxicam  1995/1/24
# 2                NaN    1994.0  D00132                 Ketoprofen  1995/2/10
# 3                NaN    2002.0  D01578                Pranoprofen  2004/2/16
# 4                NaN    2009.0  D00904          Diclofenac sodium  2009/4/28
# 5                NaN    2010.0  D01709  Loxoprofen sodium hydrate  2011/1/21
# ...              ...       ...     ...                        ...        ...
# 47062            0.0       NaN     NaN                        NaN        NaN
# 47066            0.0       NaN     NaN                        NaN        NaN
# 47079            0.0    2001.0  D03365                   Nicotine  2001/9/10
# 47081            0.0       NaN     NaN                        NaN        NaN
# 47084            0.0       NaN     NaN                        NaN        NaN
#
#       release_year                成分 variable
# 1           1995.0            ピロキシカム      id1
# 2           1995.0           ケトプロフェン      id1
# 3           2004.0        テルビナフィン塩酸塩      id1
# 4           2009.0      ジクロフェナクナトリウム      id1
# 5           2011.0  ロキソプロフェンナトリウム水和物      id1
# ...            ...               ...      ...
# 47062          NaN               NaN      NaN
# 47066          NaN               NaN      NaN
# 47079       2001.0              ニコチン      id1
# 47081          NaN               NaN      NaN
# 47084          NaN               NaN      NaN
#
# [18770 rows x 21 columns]

# %%
# !pwd
# Out:
# /c/Users/hakos/GDrive/Downloads/Research/data/yakuji
