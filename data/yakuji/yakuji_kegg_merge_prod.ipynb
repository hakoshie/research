# %%
import pandas as pd
import os
data_ke_3=pd.read_csv("../OTC/ingre_cate_len3.csv",index_col=0,encoding="shift-jis")
data_ke_2=pd.read_csv("../OTC/ingre_cate_len2.csv",index_col=0,encoding="shift-jis")
data_yaku=pd.read_csv("../yakuji/yearly/data_prod_whole.csv",encoding="shift-jis")

# %%
data_yaku.columns
# Out:
# Index(['year', 'id', 'efficacy', 'rx_agg', 'rx_pro_agg', 'rx_pro_dom',
#        'otc_agg', 'otc_pro_agg', 'otc_pro_dom', 'self_agg', 'self_pro_agg',
#        'self_pro_dom'],
#       dtype='object')

# %%
data_yaku
# Out:
#       year   id          efficacy      rx_agg  rx_pro_agg  rx_pro_dom  \
# 0     2008    0            総　　　　数  7833978217  5992764560  4467278271
# 1     2008  429          その他の腫瘍用薬   263245830    28772797    16966811
# 2     2008   43            放射性医薬品    33915325    32119390    32119390
# 3     2008   44           アレルギー用薬   313499752   242222482   118992292
# 4     2008  441           抗ヒスタミン剤     5975975     5975975     3810786
# ...    ...  ...               ...         ...         ...         ...
# 2859  2021  259  その他の泌尿生殖器官及び肛門用薬   136490590   135324184    54605284
# 2860  2021   26              外皮用薬   259437869   235701642    42594397
# 2861  2021  261          外皮用殺菌消毒剤    24360189    24137717     9355834
# 2862  2021  321            カルシウム剤     2163608     2163608      216218
# 2863  2021  821              合成麻薬    18551368    11128313     3149480
#
#         otc_agg  otc_pro_agg  otc_pro_dom  self_agg  self_pro_agg  \
# 0     598437749    582666794     15770955         0             0
# 1             0            0            0         0             0
# 2             0            0            0         0             0
# 3       2184119      2184119            0         0             0
# 4       1623776      1623776            0         0             0
# ...         ...          ...          ...       ...           ...
# 2859     399147       399147       108181    232355        232355
# 2860  186085324    185580959     51829905  49073480      49073480
# 2861   23511807     23143265      7391311         0             0
# 2862    1121801      1121801       536255         0             0
# 2863          0            0            0         0             0
#
#       self_pro_dom
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 2859             0
# 2860      14271986
# 2861             0
# 2862             0
# 2863             0
#
# [2864 rows x 12 columns]

# %%
# len 3
df_3=pd.merge(data_yaku,data_ke_3,left_on="id",right_on="id",how="left")
# sort 
df_3=df_3[df_3["id"].astype(str).str.len()==3]
df_3.sort_values(by=["year","id","release_year"]).reset_index(drop=1).to_csv("../merged/len3_prod.csv",encoding="shift-jis")
df_3
# Out:
#       year   id          efficacy     rx_agg  rx_pro_agg  rx_pro_dom  \
# 1     2008  429          その他の腫瘍用薬  263245830    28772797    16966811
# 4     2008  441           抗ヒスタミン剤    5975975     5975975     3810786
# 5     2008  442             刺激療法剤    7681290     7681290     7090756
# 6     2008  443         非特異性免疫原製剤          0           0           0
# 7     2008  449       その他のアレルギー用薬  299842487   228565217   108090750
# ...    ...  ...               ...        ...         ...         ...
# 3810  2021  259  その他の泌尿生殖器官及び肛門用薬  136490590   135324184    54605284
# 3811  2021  259  その他の泌尿生殖器官及び肛門用薬  136490590   135324184    54605284
# 3813  2021  261          外皮用殺菌消毒剤   24360189    24137717     9355834
# 3814  2021  321            カルシウム剤    2163608     2163608      216218
# 3815  2021  821              合成麻薬   18551368    11128313     3149480
#
#        otc_agg  otc_pro_agg  otc_pro_dom  self_agg  self_pro_agg  \
# 1            0            0            0         0             0
# 4      1623776      1623776            0         0             0
# 5            0            0            0         0             0
# 6            0            0            0         0             0
# 7       560343       560343            0         0             0
# ...        ...          ...          ...       ...           ...
# 3810    399147       399147       108181    232355        232355
# 3811    399147       399147       108181    232355        232355
# 3813  23511807     23143265      7391311         0             0
# 3814   1121801      1121801       536255         0             0
# 3815         0            0            0         0             0
#
#       self_pro_dom  Approved    KEGG                 Ingredient        date  \
# 1                0       NaN     NaN                        NaN         NaN
# 4                0    1990.0  D01324                Mequitazine    1994/4/4
# 5                0       NaN     NaN                        NaN         NaN
# 6                0       NaN     NaN                        NaN         NaN
# 7                0    2006.0  D00659   Azelastine hydrochloride   2006/11/1
# ...            ...       ...     ...                        ...         ...
# 3810             0    2008.0  D00718    Flavoxate hydrochloride   2008/8/22
# 3811             0    2021.0  D01007  Propiverine hydrochloride  2021/11/24
# 3813             0       NaN     NaN                        NaN         NaN
# 3814             0       NaN     NaN                        NaN         NaN
# 3815             0       NaN     NaN                        NaN         NaN
#
#       release_year          成分 variable
# 1              NaN         NaN      NaN
# 4           1994.0       メキタジン      id1
# 5              NaN         NaN      NaN
# 6              NaN         NaN      NaN
# 7           2006.0   アゼラスチン塩酸塩      id1
# ...            ...         ...      ...
# 3810        2008.0  フラボキサート塩酸塩      id1
# 3811        2021.0   プロピベリン塩酸塩      id1
# 3813           NaN         NaN      NaN
# 3814           NaN         NaN      NaN
# 3815           NaN         NaN      NaN
#
# [3279 rows x 19 columns]

# %%
# len 2
df_2=pd.merge(data_yaku,data_ke_2,left_on="id",right_on="id",how="left")
df_2=df_2[df_2["id"].astype(str).str.len()==2]
df_2.sort_values(by=["year","id","release_year"]).reset_index(drop=1).to_csv("../merged/len2_prod.csv",encoding="shift-jis")
df_2
# Out:
#       year  id efficacy     rx_agg  rx_pro_agg  rx_pro_dom    otc_agg  \
# 2     2008  43   放射性医薬品   33915325    32119390    32119390          0
# 3     2008  44  アレルギー用薬  313499752   242222482   118992292    2184119
# 4     2008  44  アレルギー用薬  313499752   242222482   118992292    2184119
# 5     2008  44  アレルギー用薬  313499752   242222482   118992292    2184119
# 6     2008  44  アレルギー用薬  313499752   242222482   118992292    2184119
# ...    ...  ..      ...        ...         ...         ...        ...
# 3962  2021  26     外皮用薬  259437869   235701642    42594397  186085324
# 3963  2021  26     外皮用薬  259437869   235701642    42594397  186085324
# 3964  2021  26     外皮用薬  259437869   235701642    42594397  186085324
# 3965  2021  26     外皮用薬  259437869   235701642    42594397  186085324
# 3966  2021  26     外皮用薬  259437869   235701642    42594397  186085324
#
#       otc_pro_agg  otc_pro_dom  self_agg  self_pro_agg  self_pro_dom  \
# 2               0            0         0             0             0
# 3         2184119            0         0             0             0
# 4         2184119            0         0             0             0
# 5         2184119            0         0             0             0
# 6         2184119            0         0             0             0
# ...           ...          ...       ...           ...           ...
# 3962    185580959     51829905  49073480      49073480      14271986
# 3963    185580959     51829905  49073480      49073480      14271986
# 3964    185580959     51829905  49073480      49073480      14271986
# 3965    185580959     51829905  49073480      49073480      14271986
# 3966    185580959     51829905  49073480      49073480      14271986
#
#       Approved    KEGG                  Ingredient        date  release_year  \
# 2          NaN     NaN                         NaN         NaN           NaN
# 3       1990.0  D01324                 Mequitazine    1994/4/4        1994.0
# 4       2006.0  D00659    Azelastine hydrochloride   2006/11/1        2006.0
# 5       2008.0  D02249       Emedastine difumarate   2009/1/13        2009.0
# 6       2012.0  D00671  Fexofenadine hydrochloride   2012/11/1        2012.0
# ...        ...     ...                         ...         ...           ...
# 3962    2008.0  D01480         Isoconazole nitrate   2008/4/22        2008.0
# 3963    2010.0  D01709   Loxoprofen sodium hydrate   2011/1/21        2011.0
# 3964    2011.0  D00282                Clotrimazole   2011/5/10        2011.0
# 3965    2009.0  D00904           Diclofenac sodium   2009/4/28        2009.0
# 3966    2006.0  D00983     Triamcinolone acetonide  2006/12/18        2006.0
#
#                     成分 variable
# 2                  NaN      NaN
# 3                メキタジン      id1
# 4            アゼラスチン塩酸塩      id1
# 5          エメダスチンフマル酸塩      id1
# 6         フェキソフェナジン塩酸塩      id1
# ...                ...      ...
# 3962        イソコナゾール硝酸塩      id2
# 3963  ロキソプロフェンナトリウム水和物      id2
# 3964          クロトリマゾール      id2
# 3965      ジクロフェナクナトリウム      id3
# 3966     トリアムシノロンアセトニド      id4
#
# [1629 rows x 19 columns]

# %%
# !pwd
# Out:
# /c/Users/hakos/GDrive/Downloads/Research/data/yakuji
