# %%
import pandas as pd
import math

# %%
f_columns=["year","id","efficacy","rx_dom","otc_dom","self_dom","stock_rx","stock_otc","stock_self"]
final_df=pd.DataFrame(columns=f_columns)
final_df
# Out:
# Empty DataFrame
# Columns: [year, id, efficacy, rx_dom, otc_dom, self_dom, stock_rx, stock_otc, stock_self]
# Index: []

# %%
def data_extract(final_df,names,header,index,year,drop=0):
    for it,name in enumerate(names):
        if drop==0:
            data=pd.read_excel(name,header=None,names=header)
        else: 
            data=pd.read_excel(name,header=None)
            data.dropna(how="all",inplace=True)
            data.dropna(how="all",inplace=True,axis=1)
            data.columns=header
            data=data.replace(',','',regex=True)
            data.reset_index(inplace=True)
        column_names=f_columns[1:]
        nrow=data.shape[0]
        for i in range(nrow):
            row_list=[data.loc[i,cname] if cname in header else 0 for cname in column_names]
            row_list.insert(0,year+it)
            # idで仕分けする場合
            # try:
            #     id=int(data.loc[i,"id"])
            # except:
            #     id=-1
            # # if isinstance(id, (int, float, complex)) and not isinstance(id, bool) and not math.isnan(id):
            # if type(id) is not str:
            #     if id>=0 and id<1000:
            #         final_df=pd.concat([final_df,pd.DataFrame(row_list,index=f_columns).T],ignore_index=False)
            # num でsubsetをとる
            try:
                num=int(data.loc[i,"num"])
            except:
                num=-1
            if type(num) is not str:
                if num>=0:
                    final_df=pd.concat([final_df,pd.DataFrame(row_list,index=f_columns).T],ignore_index=False)
    return final_df

# %% [markdown]
# 国内向け出荷額だけ見よう

# %%
# 2008
# header =[]
names=[
# "yakuji-h20tou-04.xls",
"yakuji-h20tou-05.xls",
]
year=2008
header=["id","efficacy","num","agg_agg","agg_dom","agg_ex","rx_agg","rx_dom","rx_ex","etc_agg","etc_dom","etc_ex","na","otc_agg","otc_dom","otc_ex","hou_agg","hou_dom","hou_ex","stock_agg","stock_rx","stock_etc","stock_otc","stock_hou"]
# index=190
print(len(header))
final_df=data_extract(final_df,names,header,0,year)
final_df
# Out:
# 24
#     year   id             efficacy      rx_dom    otc_dom self_dom   stock_rx  \
# 0   2008  NaN               総　　　　数  7550505188  600477366        0  814045860
# 0   2008   11              中枢神経系用薬   675395776   93249106        0   72593933
# 0   2008  111                全身麻酔剤    15448848          0        0    1017842
# 0   2008  112           催眠鎮静剤，抗不安剤    83574698    4175842        0   10718289
# 0   2008  113               抗てんかん剤    29601821       6325        0    1484160
# ..   ...  ...                  ...         ...        ...      ...        ...
# 0   2008  819  その他のアルカロイド系麻薬（天然麻薬）           0          0        0          0
# 0   2008   82           非アルカロイド系麻薬    18689310          0        0    6409949
# 0   2008  821                 合成麻薬    18689310          0        0    6409949
# 0   2008  829       その他の非アルカロイド系麻薬           0          0        0          0
# 0   2008   89               その他の麻薬           0          0        0          0
#
#    stock_otc stock_self
# ...

# %%
# 2009 - 12
names=[
# "yakuji-h21tou-04.xls",
"yakuji-h21tou-05.xls",
# "yakuji-h22tou-04.xls",
"yakuji-h22tou-05.xls",
"yakuji-h23tou-05.xls",
"yakuji-h24tou-05.xls"
]
year=2009
index=189
header=["id","efficacy","num","agg_agg","agg_dom","agg_ex","rx_agg","rx_dom","rx_ex","etc_agg","etc_dom","etc_ex","na","id2","efficacy2","otc_agg","otc_dom","otc_ex","hou_agg","hou_dom","hou_ex","stock_agg","stock_rx","stock_etc","stock_otc","stock_hou"]
print(len(header))
final_df=data_extract(final_df,names,header,index,year)
# Out:
# 26

# %%
final_df
# Out:
#     year   id             efficacy      rx_dom    otc_dom self_dom   stock_rx  \
# 0   2008  NaN               総　　　　数  7550505188  600477366        0  814045860
# 0   2008   11              中枢神経系用薬   675395776   93249106        0   72593933
# 0   2008  111                全身麻酔剤    15448848          0        0    1017842
# 0   2008  112           催眠鎮静剤，抗不安剤    83574698    4175842        0   10718289
# 0   2008  113               抗てんかん剤    29601821       6325        0    1484160
# ..   ...  ...                  ...         ...        ...      ...        ...
# 0   2012  819  その他のアルカロイド系麻薬（天然麻薬）           0          0        0          0
# 0   2012   82           非アルカロイド系麻薬    25650447          0        0    2957563
# 0   2012  821                 合成麻薬    25650447          0        0    2957563
# 0   2012  829       その他の非アルカロイド系麻薬           0          0        0          0
# 0   2012   89               その他の麻薬           0          0        0          0
#
#    stock_otc stock_self
# ...

# %%
# 2013 14
names=[
# "yakuji-h25tou-04.xls",
"yakuji-h25tou-05.xls",
# "yakuji-h26tou-04.xls",
"yakuji-h26tou-05.xls"
]
year=2013
index=189
header=["id","efficacy","num","agg_agg","agg_dom","agg_ex","rx_agg","rx_dom","rx_ex","etc_agg","etc_dom","etc_ex","na","id2","efficacy2","otc_agg","otc_dom","otc_ex","hou_agg","hou_dom","hou_ex","stock_agg","stock_rx","stock_etc","stock_otc","stock_hou"]
print(len(header))
final_df=data_extract(final_df,names,header,index,year)
# Out:
# 26

# %%
# 2015 - 18
# header =[]
names=[
# "2015-4.xls",
"2015-5.xls",
# "2016-4.xls",
"2016-5.xls",
# "2017-4.xls",
"2017-5.xls",
# "2018-4.xls",
"2018-5.xls"
]
year=2015
header=["id","efficacy","num","agg_agg","agg_dom","agg_ex","rx_agg","rx_dom","rx_ex","etc_agg","etc_dom","etc_ex","self_agg","self_dom","self_ex","id2","efficacy2","otc_agg","otc_dom","otc_ex","hou_agg","hou_dom","hou_ex","stock_agg","stock_rx","stock_etc","stock_self","stock_otc","stock_hou"]
index=190
final_df=data_extract(final_df,names,header,index,year)

# %%
# 2019
names=[
# "yakuji-2020-03.xlsx",
"yakuji-2020-04.xlsx",
]
header=["id","efficacy","num","agg_agg","agg_dom","agg_ex","rx_agg","rx_dom","rx_ex","otc_agg","otc_dom","otc_ex","self_agg","self_dom","self_ex","hou_agg","hou_dom","hou_ex","stock_agg","stock_rx","stock_otc","stock_self","stock_hou","nan"]
print(len(header))
index=139
year=2019
final_df=data_extract(final_df,names,header,index,year,drop=1)
# Out:
# 24

# %%
final_df
# Out:
#     year   id         efficacy      rx_dom    otc_dom self_dom   stock_rx  \
# 0   2008  NaN           総　　　　数  7550505188  600477366        0  814045860
# 0   2008   11          中枢神経系用薬   675395776   93249106        0   72593933
# 0   2008  111            全身麻酔剤    15448848          0        0    1017842
# 0   2008  112       催眠鎮静剤，抗不安剤    83574698    4175842        0   10718289
# 0   2008  113           抗てんかん剤    29601821       6325        0    1484160
# ..   ...  ...              ...         ...        ...      ...        ...
# 0   2019   81  アルカロイド系麻薬（天然麻薬）    15433634          －        －    7066758
# 0   2019  811     あへんアルカロイド系麻薬    15433634          －        －    7052449
# 0   2019  812      コカアルカロイド系製剤           －          －        －      14309
# 0   2019   82       非アルカロイド系麻薬    20400713          －        －    3398737
# 0   2019  821             合成麻薬    20400713          －        －    3398737
#
#    stock_otc stock_self
# 0   81874124          0
# 0   15756281          0
# ...

# %%
names=[
# "yakuji-2021-03.xlsx",
"yakuji-2021-04.xlsx",
# "yakuji-2022-03.xlsx",
"yakuji-2022-04.xlsx",
]
index=140
year=2020
header=["id","efficacy","num","agg_agg","agg_dom","agg_ex","rx_agg","rx_dom","rx_ex","otc_agg","otc_dom","otc_ex","self_agg","self_dom","self_ex","hou_agg","hou_dom","hou_ex","stock_agg","stock_rx","stock_otc","stock_self","stock_hou","nan"]
final_df=data_extract(final_df,names,header,index,year,drop=1)

# %%
final_df
# Out:
#     year   id         efficacy      rx_dom    otc_dom self_dom   stock_rx  \
# 0   2008  NaN           総　　　　数  7550505188  600477366        0  814045860
# 0   2008   11          中枢神経系用薬   675395776   93249106        0   72593933
# 0   2008  111            全身麻酔剤    15448848          0        0    1017842
# 0   2008  112       催眠鎮静剤，抗不安剤    83574698    4175842        0   10718289
# 0   2008  113           抗てんかん剤    29601821       6325        0    1484160
# ..   ...  ...              ...         ...        ...      ...        ...
# 0   2021   81  アルカロイド系麻薬（天然麻薬）    15995397          －        －    9205992
# 0   2021  811     あへんアルカロイド系麻薬    15995397          －        －    9205992
# 0   2021  812      コカアルカロイド系製剤           －          －        －          －
# 0   2021   82       非アルカロイド系麻薬    18788170          －        －    3221658
# 0   2021  821             合成麻薬    18788170          －        －    3221658
#
#    stock_otc stock_self
# 0   81874124          0
# 0   15756281          0
# ...

# %%
final_df=final_df.replace(',','',regex=True)
final_df=final_df.replace(' ','0',regex=True)
final_df=final_df.replace('－','0',regex=True)
final_df=final_df.sort_values("year")
final_df=final_df.dropna(subset="efficacy")
final_df["id"].fillna(0,inplace=True)
final_df=final_df.set_index("year")
# for col in final_df.columns:
#     if col!="efficacy":
#         final_df[col]=final_df[col].astype(int)
# final_df=final_df.set_index("year")
final_df["id"]=final_df["id"].astype(int)
final_df
# Out:
#        id          efficacy      rx_dom    otc_dom  self_dom   stock_rx  \
# year
# 2008    0            総　　　　数  7550505188  600477366         0  814045860
# 2008  429          その他の腫瘍用薬   262377735          0         0   29713902
# 2008   43            放射性医薬品    33390201          0         0     340580
# 2008   44           アレルギー用薬   307911130    2296067         0   29151149
# 2008  441           抗ヒスタミン剤     6003463    1592384         0     587915
# ...   ...               ...         ...        ...       ...        ...
# 2021  259  その他の泌尿生殖器官及び肛門用薬   138820067     312266     94813   38296017
# 2021   26              外皮用薬   242442964  157209011  46244232   41748859
# 2021  261          外皮用殺菌消毒剤    25664469   21658072         0    3202682
# 2021  321            カルシウム剤     2472650    1133944         0     399584
# 2021  821              合成麻薬    18788170          0         0    3221658
#
#      stock_otc stock_self
# year
# 2008  81874124          0
# 2008         0          0
# ...

# %%
final_df.to_csv("data_ship_whole.csv",encoding="shift-jis")

# %%
# final_df.plot()

# %%
# final_df.plot(y=["stock_otc","otc_dom"])
# final_df.plot(y=["stock_self","self_dom"])
