# %%
import pandas as pd

# %%
f_columns=["year","id","efficacy","rx_agg","rx_pro_agg","rx_pro_dom","otc_agg","otc_pro_agg","otc_pro_dom","self_agg","self_pro_agg","self_pro_dom"]
final_df=pd.DataFrame(columns=f_columns)
final_df
# Out:
# Empty DataFrame
# Columns: [year, id, efficacy, rx_agg, rx_pro_agg, rx_pro_dom, otc_agg, otc_pro_agg, otc_pro_dom, self_agg, self_pro_agg, self_pro_dom]
# Index: []

# %%
def data_extract(final_df,names,header,index,year,drop=0):
    for it,name in enumerate(names):
        if drop==0:
            data=pd.read_excel(name,header=None,names=header)
        else: 
            data=pd.read_excel(name,header=None)
            # data.dropna(how="all",inplace=True)
            data.dropna(how="all",inplace=True,axis=1)
            data.columns=header
            data=data.replace(',','',regex=True)
            data.reset_index(inplace=True)
        column_names=f_columns[1:]
        nrow=data.shape[0]
        for i in range(nrow):
            row_list=[data.loc[i,cname] if cname in header else 0 for cname in column_names]
            row_list.insert(0,year+it)
            
            # idで仕分けする場合
            # try:
            #     id=int(data.loc[i,"id"])
            # except:
            #     id=-1
            # # if isinstance(id, (int, float, complex)) and not isinstance(id, bool) and not math.isnan(id):
            # if type(id) is not str:
            #     if id>=0 and id<1000:
            #         final_df=pd.concat([final_df,pd.DataFrame(row_list,index=f_columns).T],ignore_index=False)
            # num でsubsetをとる
            try:
                num=int(data.loc[i,"num"])
                # print(i,num)
            except:
                # print(i,data.loc[i,"num"])
                num=-1
            if type(num) is not str:
                if num>=0:
                    final_df=pd.concat([final_df,pd.DataFrame(row_list,index=f_columns).T],ignore_index=False)
    return final_df

# %%
# 2008
# header =[]
names=[
"yakuji-h20tou-04.xls",
# "yakuji-h20tou-05.xls",
]
year=2008
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","null","etc_pro_dom","etc_pro_im","etc_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
# index=190
print(len(header))
final_df=data_extract(final_df,names,header,0,year)
final_df
# Out:
# 29
#     year   id             efficacy      rx_agg  rx_pro_agg  rx_pro_dom  \
# 0   2008  NaN               総　　　　数  7833978217  5992764560  4467278271
# 0   2008   11              中枢神経系用薬   701071447   520792818   368465852
# 0   2008  111                全身麻酔剤    15585527     6259240     6206990
# 0   2008  112           催眠鎮静剤，抗不安剤    83589943    73256843    25608087
# 0   2008  113               抗てんかん剤    30357429    30357429    22648559
# ..   ...  ...                  ...         ...         ...         ...
# 0   2008  819  その他のアルカロイド系麻薬（天然麻薬）           0           0           0
# 0   2008   82           非アルカロイド系麻薬    22943287     1526045      450010
# 0   2008  821                 合成麻薬    22943287     1526045      450010
# 0   2008  829       その他の非アルカロイド系麻薬           0           0           0
# 0   2008   89               その他の麻薬           0           0           0
#
#       otc_agg otc_pro_agg otc_pro_dom self_agg self_pro_agg self_pro_dom
# ...

# %%
# 何もない列があるP
#2009 - 2012
names=[
"yakuji-h21tou-04.xls",
# "yakuji-h21tou-05.xls",
"yakuji-h22tou-04.xls",
# "yakuji-h22tou-05.xls"
"yakuji-h23tou-04.xls",
# "yakuji-h25tou-05.xls",
"yakuji-h24tou-04.xls",
# "yakuji-h26tou-05.xls"
]
year=2009
index=189
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","null","id2","efficacy2","etc_pro_dom","etc_pro_im","etc_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
final_df=data_extract(final_df,names,header,index,year)
# Out:
# 31

# %%
final_df
# Out:
#     year   id             efficacy      rx_agg  rx_pro_agg  rx_pro_dom  \
# 0   2008  NaN               総　　　　数  7833978217  5992764560  4467278271
# 0   2008   11              中枢神経系用薬   701071447   520792818   368465852
# 0   2008  111                全身麻酔剤    15585527     6259240     6206990
# 0   2008  112           催眠鎮静剤，抗不安剤    83589943    73256843    25608087
# 0   2008  113               抗てんかん剤    30357429    30357429    22648559
# ..   ...  ...                  ...         ...         ...         ...
# 0   2012  819  その他のアルカロイド系麻薬（天然麻薬）           0           0           0
# 0   2012   82           非アルカロイド系麻薬    24126104     8066082     7602026
# 0   2012  821                 合成麻薬    24126104     8066082     7602026
# 0   2012  829       その他の非アルカロイド系麻薬           0           0           0
# 0   2012   89               その他の麻薬           0           0           0
#
#       otc_agg otc_pro_agg otc_pro_dom self_agg self_pro_agg self_pro_dom
# ...

# %%
# 2013 -14
# 何もない列があるP
names=[
"yakuji-h25tou-04.xls",
# "yakuji-h25tou-05.xls",
"yakuji-h26tou-04.xls",
# "yakuji-h26tou-05.xls"
]
year=2013
index=189
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","null","id2","efficacy2","etc_pro_dom","etc_pro_im","etc_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
final_df=data_extract(final_df,names,header,index,year)
# Out:
# 31

# %%
# 2015 - 2018
# header =[]
names=[
"2015-4.xls",
# "2015-5.xls",
"2016-4.xls",
# "2016-5.xls",
"2017-4.xls",
# "2017-5.xls",
"2018-4.xls",
# "2018-5.xls"
]
year=2015
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","etc_agg","etc_pro_agg","etc_pro_dom","etc_pro_im","etc_im","id2","efficacy2","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
index=190
final_df=data_extract(final_df,names,header,index,year)

# %%
final_df
# Out:
#     year   id             efficacy      rx_agg  rx_pro_agg  rx_pro_dom  \
# 0   2008  NaN               総　　　　数  7833978217  5992764560  4467278271
# 0   2008   11              中枢神経系用薬   701071447   520792818   368465852
# 0   2008  111                全身麻酔剤    15585527     6259240     6206990
# 0   2008  112           催眠鎮静剤，抗不安剤    83589943    73256843    25608087
# 0   2008  113               抗てんかん剤    30357429    30357429    22648559
# ..   ...  ...                  ...         ...         ...         ...
# 0   2018  819  その他のアルカロイド系麻薬（天然麻薬）           0           0           0
# 0   2018   82           非アルカロイド系麻薬    20812493     8794217     8298867
# 0   2018  821                 合成麻薬    20812493     8794217     8298867
# 0   2018  829       その他の非アルカロイド系麻薬           0           0           0
# 0   2018   89               その他の麻薬           0           0           0
#
#       otc_agg otc_pro_agg otc_pro_dom self_agg self_pro_agg self_pro_dom
# ...

# %%
# 2019
names=[
"yakuji-2020-03.xlsx",
# "yakuji-2020-04.xlsx",
]
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
# print(len(header))
index=139
year=2019
final_df=data_extract(final_df,names,header,index,year,drop=1)

# %%
final_df
# Out:
#     year   id         efficacy      rx_agg  rx_pro_agg  rx_pro_dom    otc_agg  \
# 0   2008  NaN           総　　　　数  7833978217  5992764560  4467278271  598437749
# 0   2008   11          中枢神経系用薬   701071447   520792818   368465852   92236700
# 0   2008  111            全身麻酔剤    15585527     6259240     6206990          0
# 0   2008  112       催眠鎮静剤，抗不安剤    83589943    73256843    25608087    4106759
# 0   2008  113           抗てんかん剤    30357429    30357429    22648559       6325
# ..   ...  ...              ...         ...         ...         ...        ...
# 0   2019   81  アルカロイド系麻薬（天然麻薬）    16615181    16615181    13195141          －
# 0   2019  811     あへんアルカロイド系麻薬    16597555    16597555    13177515          －
# 0   2019  812      コカアルカロイド系製剤       17626       17626       17626          －
# 0   2019   82       非アルカロイド系麻薬    19813744     8727992     5813356          －
# 0   2019  821             合成麻薬    19813744     8727992     5813356          －
#
# ...

# %%
# 2020 - 2021
names=[
"yakuji-2021-03.xlsx",
# "yakuji-2021-04.xlsx",
"yakuji-2022-03.xlsx",
# "yakuji-2022-04.xlsx",
]
index=140
year=2020
header=["id","efficacy","num","agg_agg","agg_pro","agg_pro_dom","agg_pro_im","agg_im","rx_agg","rx_pro_agg","rx_pro_dom","rx_pro_im","rx_im","otc_agg","otc_pro_agg","otc_pro_dom","otc_pro_im","otc_im","self_agg","self_pro_agg","self_pro_dom","self_pro_im","self_im","hou_agg","hou_pro_agg","hou_pro_dom","hou_pro_im","hou_im"]
print(len(header))
final_df=data_extract(final_df,names,header,index,year,drop=1)
# Out:
# 28

# %%
final_df
# Out:
#     year   id         efficacy      rx_agg  rx_pro_agg  rx_pro_dom    otc_agg  \
# 0   2008  NaN           総　　　　数  7833978217  5992764560  4467278271  598437749
# 0   2008   11          中枢神経系用薬   701071447   520792818   368465852   92236700
# 0   2008  111            全身麻酔剤    15585527     6259240     6206990          0
# 0   2008  112       催眠鎮静剤，抗不安剤    83589943    73256843    25608087    4106759
# 0   2008  113           抗てんかん剤    30357429    30357429    22648559       6325
# ..   ...  ...              ...         ...         ...         ...        ...
# 0   2021   81  アルカロイド系麻薬（天然麻薬）    16428331    16428331    16428331          －
# 0   2021  811     あへんアルカロイド系麻薬    16428331    16428331    16428331          －
# 0   2021  812      コカアルカロイド系製剤           －           －           －          －
# 0   2021   82       非アルカロイド系麻薬    18551368    11128313     3149480          －
# 0   2021  821             合成麻薬    18551368    11128313     3149480          －
#
# ...

# %%
# for column in final_df.columns:
final_df=final_df.replace(',','',regex=True)
final_df=final_df.replace(' ','0',regex=True)
final_df=final_df.replace('－','0',regex=True)
final_df=final_df.sort_values("year")
final_df=final_df.dropna(subset="efficacy")
final_df["id"].fillna(0,inplace=True)
final_df=final_df.set_index("year")
# for col in final_df.columns:
#     if col!="efficacy":
#         final_df[col]=final_df[col].astype(int)
final_df["id"]=final_df["id"].astype(int)
# final_df=final_df.set_index("year")
final_df
# Out:
#        id          efficacy      rx_agg  rx_pro_agg  rx_pro_dom    otc_agg  \
# year
# 2008    0            総　　　　数  7833978217  5992764560  4467278271  598437749
# 2008  429          その他の腫瘍用薬   263245830    28772797    16966811          0
# 2008   43            放射性医薬品    33915325    32119390    32119390          0
# 2008   44           アレルギー用薬   313499752   242222482   118992292    2184119
# 2008  441           抗ヒスタミン剤     5975975     5975975     3810786    1623776
# ...   ...               ...         ...         ...         ...        ...
# 2021  259  その他の泌尿生殖器官及び肛門用薬   136490590   135324184    54605284     399147
# 2021   26              外皮用薬   259437869   235701642    42594397  186085324
# 2021  261          外皮用殺菌消毒剤    24360189    24137717     9355834   23511807
# 2021  321            カルシウム剤     2163608     2163608      216218    1121801
# 2021  821              合成麻薬    18551368    11128313     3149480          0
#
# ...

# %%
final_df.to_csv("data_prod_whole.csv",encoding="shift-jis")

# %%
# final_df.plot()

# %%
# final_df.plot(y=["otc_agg","otc_pro_agg"])
# final_df.plot(y=["self_agg","self_pro_agg"])
